# %% [markdown]
# # Vertica columns definition updates
#
# ## Problem
#
# Following the migration of analytics data tables CTG Vertica database to the data lake, table and column documentation in the data lake catalog has not been updated. It would be a significant manual effort to recapture all the business definitions in the data lake data dictionary (catalog).
#
# Intuit uses Alation Data Catalog as their central meta-data repository. The CTG Vertica data definitions we exported from the Alation Data Catalog and made available as Google sheet.
#
# We want to leverage the legacy documentation now available in a Google sheet to programmatically update the data lake description for the migrated tables and columns to the data lake. There are three scenarios:
#
# 1. table moved to the data lake and with the same name as the corresponding Vertica table
# 2. table moved to the data lake under a new name - a table migration mapping existing in the form of a Google sheet identifying source and target table.
# 3. columns may have been replicated in numerous different tables in the data lake, for which we may not have a table mapping
#
# Scenario #1 was easily resolved using the Alation Catalog Sync feature available in Alation. This resulted in the update of 292 tables and their columns documentation.
#
# The Alation Catalog sync feature cannot be used where table names are different. In this case, we need to use a scripted approach, leveraging Python and Pandas dataframes, to copy column level definitions from Vertica document to data lake. This approach relies on matching column names across all tables - scenario #3. The estimate is that over 2800 column definitions can be updated using this approach.
#
# Finally, table level descriptions will be migrated to the data lake based on the migration table map. This potentially add another 300+ data lake table descriptions.
#
#
# ## Approach
#
# Creates following data frames:
# * `df_vertica_desc`: vertica data catalog exported descriptions (read from Google Sheet)
#     * create a deduplicated version of column descriptions, retaining the longest description as the preferred column description
#     * create a deduplicated version of table descriptions, also retaining the longest description
# * `df_alation_catalog`: existing alation data catalog export, from which to extract table and column objects with null descriptions - to avoid overwrite existing decriptions
#
# These two catalogs can be merged on the column name to associate the Vertica description to the data lake column of the same name.
#
# * `df_cg_datasets`: Data Solution Engineering is working in parallel to manually created documentation. Load the work in progress descriptions into a data set that will be used to remove conflicts from the merged Vertica / Alation data sets (above).
#
# * `df_new_definitions`: merge of vertica_desc and df_alation_catalog matched on column name, excluding objects already present in cg_datasets. Removing column descriptions created by DSE can be done with a merge left join that excludes matching records (i.e. where DSE table name is null) - that way, only the rows from the merge catalog that do not have a match in the cg datasets will remain.
#
# Use a similar approach as above to bring in table leve definition for tables where names do not match, to create a data lake table level description update.
# * `df_dl_map`: Google sheet containing from / to data lake tables, to enable updating data lake table descriptions where table name does not match Vertica table name. These records will be appended to the  `df_new_definitions` data frame.
#
# Finally, create a process to export to CSV new definitions, creating on CSV file per data lake table, as per DSE data catalog update process.

# %%
import pandas as pd
import numpy as np
import os

import gspread

from datetime import datetime, timedelta
from df2gspread import df2gspread as d2g
from oauth2client.service_account import ServiceAccountCredentials

# import plotly.graph_objs as go
# import plotly.express as px

# from plotly.offline import iplot

# %% [markdown]
# ## Configurations

# %%
# Alation current data catalog - from local export files
CATALOG_LOCAL_PATH = "S:/Data/alation_data"

# Alation catalog upload Github project 
GITHUB = {"LOCAL_PATH": "S:/Development/github/intuit/cg_datasets/hive",
          "DATA_CATALOG_FOLDER_NAME": "datacatalog",
          "CATALOG_FILE_NAME_SUFFIX": "vertica-legacy"}

# generic descriptions to be ignored
VERTICA_DESC_EXCEPTIONS = [
    "7216 approved",
    "Please refer to Consumer_dm.dim_agent",
    "Field not populated with any data as of 11/13/2018"
]

# %%
# Google sheet KPI book
VERTICA_SPREADSHEET_ID ='<removed>'
VERTICA_SHEET = 'vertica_descriptions'

DL_MAP_SPREADSHEET_ID = '<removed>'
DL_MAP_SHEET = 'table_list'

GOOGLE_TOKEN_PATH = "./creds/"
SERVICE_ACCOUNT_FILE = os.path.join(GOOGLE_TOKEN_PATH,'<removed>.json')
SCOPES = ["https://www.googleapis.com/auth/spreadsheets"]

print(SERVICE_ACCOUNT_FILE)
print(SCOPES)
# Out:
# ./creds/cg-data-analytics-4aadfb13b1cf.json
# ['https://www.googleapis.com/auth/spreadsheets']

# %% [markdown]
# ## Connection

# %%
# connect to service account and generate a Google Sheet client
CREDENTIALS = ServiceAccountCredentials.from_json_keyfile_name(SERVICE_ACCOUNT_FILE, SCOPES)
gc = gspread.authorize(CREDENTIALS)

print(gc)
# Out:
# <gspread.client.Client object at 0x00000244529B4FD0>

# %%
# connect workbooks
vertica_workbook = gc.open_by_key(VERTICA_SPREADSHEET_ID)
dl_map_workbook = gc.open_by_key(DL_MAP_SPREADSHEET_ID)

print(vertica_workbook)
print(dl_map_workbook)
# Out:
# <Spreadsheet 'vertica_descriptions_consolidated' id:1UsEVy62FB8Dd36uwPcRX6w4nCazP1JBSRjiN-mSOp48>
# <Spreadsheet 'ctg_vertica_table_documentation_migration' id:1lKAtO52l1np5Bu78T3aR_LJIJk7Qwo9fDiGkvJkntgg>

# %% [markdown]
# ### Define functions

# %%
def read_gsheet(book,sheet):
    worksheet = book.worksheet(sheet)
    table = worksheet.get_all_values()
    return pd.DataFrame(table[1:],columns = table[0])

# %% [markdown]
# ### Main Execution

# %% [markdown]
# #### Read vertica to data lake migration data lake table map

# %%
df_dl_map = read_gsheet(dl_map_workbook, DL_MAP_SHEET)
df_dl_map['key'] = df_dl_map['CTG Vertica Key']

df_dl_map.shape
# Out:
# (826, 11)

# %%
df_dl_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826 entries, 0 to 825
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CTG Vertica Key         826 non-null    object
#  1   CTG Vertica AWS schema  826 non-null    object
#  2   CTG Vertica AWS table   826 non-null    object
#  3   Data Lake Key           826 non-null    object
#  4   Data Lake Schema        826 non-null    object
#  5   Data Lake Table         826 non-null    object
#  6   Same schema             826 non-null    object
#  7   Same table              826 non-null    object
#  8   Sync Type               826 non-null    object
#  9   Status                  826 non-null    object
#  10  key                     826 non-null    object
# dtypes: object(11)
# memory usage: 71.1+ KB

# %%
df_dl_map.head()
# Out:
#                      CTG Vertica Key CTG Vertica AWS schema  \
# 0  backup_schema.tto_mapping_segment          backup_schema
# 1    bup_dm.amex_fact_ad_performance                 bup_dm
# 2                 bup_dm.cfg_etl_job                 bup_dm
# 3          bup_dm.dim_bup_ad_content                 bup_dm
# 4            bup_dm.dim_bup_agencies                 bup_dm
#
#       CTG Vertica AWS table                    Data Lake Key Data Lake Schema  \
# 0       tto_mapping_segment      tax_src.tto_mapping_segment          tax_src
# 1  amex_fact_ad_performance  bup_dm.amex_fact_ad_performance           bup_dm
# 2               cfg_etl_job               bup_dm.cfg_etl_job           bup_dm
# 3        dim_bup_ad_content        bup_dm.dim_bup_ad_content           bup_dm
# 4          dim_bup_agencies          bup_dm.dim_bup_agencies           bup_dm
#
#             Data Lake Table Same schema Same table     Sync Type  \
# 0       tto_mapping_segment       FALSE       TRUE  Schema Level
# 1  amex_fact_ad_performance        TRUE       TRUE  Schema Level
# 2               cfg_etl_job        TRUE       TRUE  Schema Level
# 3        dim_bup_ad_content        TRUE       TRUE  Schema Level
# 4          dim_bup_agencies        TRUE       TRUE  Schema Level
#
#          Status                                key
# 0  Out of Scope  backup_schema.tto_mapping_segment
# 1  Out of Scope    bup_dm.amex_fact_ad_performance
# 2  Out of Scope                 bup_dm.cfg_etl_job
# 3  Out of Scope          bup_dm.dim_bup_ad_content
# 4  Out of Scope            bup_dm.dim_bup_agencies

# %%
df_dl_map['same_table_name'] = df_dl_map['CTG Vertica AWS table'] == df_dl_map['Data Lake Table']

df_dl_map[['Data Lake Table','same_table_name']].groupby('same_table_name').count()
# Out:
#                  Data Lake Table
# same_table_name
# False                        338
# True                         488

# %%
# retain tables with different names 
df_dl_map = df_dl_map[~df_dl_map.same_table_name]

df_dl_map.head()
# Out:
#                     CTG Vertica Key CTG Vertica AWS schema  \
# 33     bup_source.src_impact_radius             bup_source
# 34            bup_source.src_marcus             bup_source
# 36           bup_source.src_rakuten             bup_source
# 39            bup_stage.stg_rakuten              bup_stage
# 41  bup_stage.stg_rakuten_signature              bup_stage
#
#     CTG Vertica AWS table                              Data Lake Key  \
# 33      src_impact_radius             smartmoney_src.src_impact_mint
# 34             src_marcus               bup_src.v_partner_marcus_etl
# 36            src_rakuten            smartmoney_src.src_rakuten_mint
# 39            stg_rakuten            smartmoney_stg.stg_rakuten_mint
# 41  stg_rakuten_signature  smartmoney_stg.stg_rakuten_signature_qetl
#
#    Data Lake Schema             Data Lake Table Same schema Same table  \
# 33   smartmoney_src             src_impact_mint       FALSE      FALSE
# 34          bup_src        v_partner_marcus_etl       FALSE      FALSE
# 36   smartmoney_src            src_rakuten_mint       FALSE      FALSE
# 39   smartmoney_stg            stg_rakuten_mint       FALSE      FALSE
# 41   smartmoney_stg  stg_rakuten_signature_qetl       FALSE      FALSE
#
#        Sync Type Status                              key  same_table_name
# 33  Column Level            bup_source.src_impact_radius            False
# 34  Column Level                   bup_source.src_marcus            False
# 36  Column Level                  bup_source.src_rakuten            False
# 39  Column Level                   bup_stage.stg_rakuten            False
# 41  Column Level         bup_stage.stg_rakuten_signature            False

# %%
df_dl_map.shape
# Out:
# (338, 12)

# %%
df_dl_map.sample(50)
# Out:
#                                        CTG Vertica Key  \
# 593  ctg_analytics.sub_clickstream_visitor_nonffa_f...
# 610  ctg_analytics_secure_src.trn_responsys_tt_skipped
# 322        consumer_source.src_document_service_expert
# 90                          care_dwh.dim_ewfm_seg_code
# 715                        mint_dwh.transaction_bankcc
# 378     consumer_source.src_snap_qbse_total_subs_daily
# 432                       ctg_analyst_layer.cases_uids
# 480        ctg_analyst_layer.inet_turbotax_api_details
# 293  consumer_source.src_braze_turbotax_users_canva...
# 584                  ctg_analytics.lkp_item_alias_rank
# 111                    care_dwh.fact_cc_source_mapping
# 455    ctg_analyst_layer.inet_dim_billing_transactions
# 586               ctg_analytics.sub_auth_id_multifiler
# 60                       care_dwh.axc_analytics_events
# 61                              care_dwh.axc_bookmarks
# 87                             care_dwh.dim_ewfm_persp
# 453    ctg_analyst_layer.inet_agg_billing_transactions
# 58                                  care_dwh.axc_users
# 136                             care_dwh.sf_new_worker
# 103                              care_dwh.ewfm_det_seg
# 48                                  care_dwh.axc_posts
# 110                  care_dwh.fact_cc_contact_verbatim
# 392                     cs_dwh.alert_credit_monitoring
# 591       ctg_analytics.sub_clickstream_tt_start_first
# 294  consumer_source.src_braze_turbotax_users_canva...
# 382   consumer_source.src_sw_agent_schedule_preference
# 648                         matt_dwh.ttl_retail_revoke
# 106                           care_dwh.fact_cc_contact
# 62                            care_dwh.axc_communities
# 465        ctg_analyst_layer.inet_dim_interaction_dtmf
# 46                            care_dwh.axc_communities
# 439        ctg_analyst_layer.ctg_care_cct_interactions
# 456             ctg_analyst_layer.inet_dim_call_result
# 348  consumer_source.src_mxs_idp_ml_casepop_questio...
# 387         consumer_source.src_thrive_cto_prod_survey
# 269  consumer_source.src_braze_mint_users_behaviors...
# 268  consumer_source.src_braze_mint_users_behaviors...
# 320       consumer_source.src_cvdim_sales_order_status
# 638                                matt_dwh.etx_orders
# 114                  care_dwh.fact_cg_content_metadata
# 609     ctg_analytics_secure_src.trn_responsys_tt_sent
# 491  ctg_analyst_layer.monetization_analytics_maste...
# 116                              care_dwh.fact_refunds
# 506                     ctg_analyst_layer.w2_auth_base
# 64                                  care_dwh.axc_posts
# 102                          care_dwh.ewfm_aud_gen_seg
# 278  consumer_source.src_braze_mint_users_messages_...
# 301  consumer_source.src_braze_turbotax_users_messa...
# 57                                 care_dwh.axc_topics
# 471   ctg_analyst_layer.inet_dim_interaction_sentiment
#
#        CTG Vertica AWS schema  \
# 593             ctg_analytics
# 610  ctg_analytics_secure_src
# 322           consumer_source
# 90                   care_dwh
# 715                  mint_dwh
# 378           consumer_source
# 432         ctg_analyst_layer
# 480         ctg_analyst_layer
# 293           consumer_source
# 584             ctg_analytics
# 111                  care_dwh
# 455         ctg_analyst_layer
# 586             ctg_analytics
# 60                   care_dwh
# 61                   care_dwh
# 87                   care_dwh
# 453         ctg_analyst_layer
# 58                   care_dwh
# 136                  care_dwh
# 103                  care_dwh
# 48                   care_dwh
# 110                  care_dwh
# 392                    cs_dwh
# 591             ctg_analytics
# 294           consumer_source
# 382           consumer_source
# 648                  matt_dwh
# 106                  care_dwh
# 62                   care_dwh
# 465         ctg_analyst_layer
# 46                   care_dwh
# 439         ctg_analyst_layer
# 456         ctg_analyst_layer
# 348           consumer_source
# 387           consumer_source
# 269           consumer_source
# 268           consumer_source
# 320           consumer_source
# 638                  matt_dwh
# 114                  care_dwh
# 609  ctg_analytics_secure_src
# 491         ctg_analyst_layer
# 116                  care_dwh
# 506         ctg_analyst_layer
# 64                   care_dwh
# 102                  care_dwh
# 278           consumer_source
# 301           consumer_source
# 57                   care_dwh
# 471         ctg_analyst_layer
#
#                                  CTG Vertica AWS table  \
# 593               sub_clickstream_visitor_nonffa_first
# 610                           trn_responsys_tt_skipped
# 322                        src_document_service_expert
# 90                                   dim_ewfm_seg_code
# 715                                 transaction_bankcc
# 378                     src_snap_qbse_total_subs_daily
# 432                                         cases_uids
# 480                          inet_turbotax_api_details
# 293         src_braze_turbotax_users_canvas_conversion
# 584                                lkp_item_alias_rank
# 111                             fact_cc_source_mapping
# 455                      inet_dim_billing_transactions
# 586                             sub_auth_id_multifiler
# 60                                axc_analytics_events
# 61                                       axc_bookmarks
# 87                                      dim_ewfm_persp
# 453                      inet_agg_billing_transactions
# 58                                           axc_users
# 136                                      sf_new_worker
# 103                                       ewfm_det_seg
# 48                                           axc_posts
# 110                           fact_cc_contact_verbatim
# 392                            alert_credit_monitoring
# 591                     sub_clickstream_tt_start_first
# 294              src_braze_turbotax_users_canvas_entry
# 382                   src_sw_agent_schedule_preference
# 648                                  ttl_retail_revoke
# 106                                    fact_cc_contact
# 62                                     axc_communities
# 465                          inet_dim_interaction_dtmf
# 46                                     axc_communities
# 439                          ctg_care_cct_interactions
# 456                               inet_dim_call_result
# 348     src_mxs_idp_ml_casepop_question_classification
# 387                         src_thrive_cto_prod_survey
# 269           src_braze_mint_users_behaviors_uninstall
# 268  src_braze_mint_users_behaviors_subscriptiongro...
# 320                       src_cvdim_sales_order_status
# 638                                         etx_orders
# 114                           fact_cg_content_metadata
# 609                              trn_responsys_tt_sent
# 491               monetization_analytics_master_ytd_vw
# 116                                       fact_refunds
# 506                                       w2_auth_base
# 64                                           axc_posts
# 102                                   ewfm_aud_gen_seg
# 278           src_braze_mint_users_messages_email_send
# 301  src_braze_turbotax_users_messages_email_softbo...
# 57                                          axc_topics
# 471                     inet_dim_interaction_sentiment
#
#                                          Data Lake Key  \
# 593  tax_src.sub_clickstream_visitor_nonffa_first_g...
# 610             tax_src.src_responsys_turbotax_skipped
# 322             tax_src.src_fdp_document_service_event
# 90                    ent_ewfm_tcsdbowner_dwh.seg_code
# 715  smartmoney_dm.transaction_bankcc_full_load and...
# 378                sbseg_dm.snap_qbse_total_subs_daily
# 432                               tax_rpt.rpt_case_uid
# 480               ivr_src.src_inet_turbotax_api_detail
# 293       tax_src.src_braze_turbotax_canvas_conversion
# 584  tax_src.lkp_item_alias_rank/lkp_item_alias_ran...
# 111                   ent_dwr_dwh.dw_cc_source_mapping
# 455           ivr_src.src_inet_dim_billing_transaction
# 586              tax_src.sub_auth_id_multifiler_global
# 60                      tax_src.axc_ca_analytic_events
# 61                            tax_src.axc_ca_bookmarks
# 87                       ent_ewfm_tcsdbowner_dwh.persp
# 453               ivr_rpt.agg_inet_billing_transaction
# 58                                tax_src.axc_us_users
# 136                         ent_elm_dwh.elm_new_worker
# 103                ent_ewfm_tcsdbowner_dwh.aud_det_seg
# 48                                tax_src.axc_us_posts
# 110                tax_dm.fact_sf_b2c_contact_verbatim
# 392                            ued_creditscore_dwh.n/a
# 591      tax_src.sub_clickstream_tt_start_first_global
# 294            tax_src.src_braze_turbotax_canvas_entry
# 382       tax_ws.src_sw_agent_schedule_preference_temp
# 648                      tax_src.src_ttl_retail_revoke
# 106                         tax_dm.fact_sf_b2c_contact
# 62                          tax_src.axc_ca_communities
# 465              ivr_src.src_inet_dim_interaction_dtmf
# 46                          tax_src.axc_us_communities
# 439                  tax_rpt.rpt_care_cct_interactions
# 456                   ivr_src.src_inet_dim_call_result
# 348   serde_dwh.idp_ml_casepop_question_classification
# 387                         thrive_dwh.cto_prod_survey
# 269  smartmoney_src.src_braze_mint_behaviors_uninstall
# 268  smartmoney_src.src_braze_mint_behaviors_statec...
# 320                  ent_cv_dwh.dim_sales_order_status
# 638                      tax_src.src_efe_non_rt_orders
# 114                     ued_oicms_dwh.content_metadata
# 609                tax_src.src_responsys_turbotax_sent
# 491  tax_rpt.tax_rpt.monetization_analytics_master_...
# 116                          tax_dm.fact_sf_b2c_refund
# 506                          tax_src.w2_auth_base_ty19
# 64                                tax_src.axc_ca_posts
# 102                ent_ewfm_tcsdbowner_dwh.aud_gen_seg
# 278           smartmoney_src.src_braze_mint_email_send
# 301        tax_src.src_braze_turbotax_email_softbounce
# 57                               tax_src.axc_us_topics
# 471         ivr_src.src_inet_dim_interaction_sentiment
#
#             Data Lake Schema  \
# 593                  tax_src
# 610                  tax_src
# 322                  tax_src
# 90   ent_ewfm_tcsdbowner_dwh
# 715            smartmoney_dm
# 378                 sbseg_dm
# 432                  tax_rpt
# 480                  ivr_src
# 293                  tax_src
# 584                  tax_src
# 111              ent_dwr_dwh
# 455                  ivr_src
# 586                  tax_src
# 60                   tax_src
# 61                   tax_src
# 87   ent_ewfm_tcsdbowner_dwh
# 453                  ivr_rpt
# 58                   tax_src
# 136              ent_elm_dwh
# 103  ent_ewfm_tcsdbowner_dwh
# 48                   tax_src
# 110                   tax_dm
# 392      ued_creditscore_dwh
# 591                  tax_src
# 294                  tax_src
# 382                   tax_ws
# 648                  tax_src
# 106                   tax_dm
# 62                   tax_src
# 465                  ivr_src
# 46                   tax_src
# 439                  tax_rpt
# 456                  ivr_src
# 348                serde_dwh
# 387               thrive_dwh
# 269           smartmoney_src
# 268           smartmoney_src
# 320               ent_cv_dwh
# 638                  tax_src
# 114            ued_oicms_dwh
# 609                  tax_src
# 491                  tax_rpt
# 116                   tax_dm
# 506                  tax_src
# 64                   tax_src
# 102  ent_ewfm_tcsdbowner_dwh
# 278           smartmoney_src
# 301                  tax_src
# 57                   tax_src
# 471                  ivr_src
#
#                                        Data Lake Table Same schema Same table  \
# 593        sub_clickstream_visitor_nonffa_first_global       FALSE      FALSE
# 610                     src_responsys_turbotax_skipped       FALSE      FALSE
# 322                     src_fdp_document_service_event       FALSE      FALSE
# 90                                            seg_code       FALSE      FALSE
# 715  transaction_bankcc_full_load and transaction_b...       FALSE      FALSE
# 378                         snap_qbse_total_subs_daily       FALSE      FALSE
# 432                                       rpt_case_uid       FALSE      FALSE
# 480                       src_inet_turbotax_api_detail       FALSE      FALSE
# 293               src_braze_turbotax_canvas_conversion       FALSE      FALSE
# 584         lkp_item_alias_rank/lkp_item_alias_rank_vw       FALSE      FALSE
# 111                               dw_cc_source_mapping       FALSE      FALSE
# 455                   src_inet_dim_billing_transaction       FALSE      FALSE
# 586                      sub_auth_id_multifiler_global       FALSE      FALSE
# 60                              axc_ca_analytic_events       FALSE      FALSE
# 61                                    axc_ca_bookmarks       FALSE      FALSE
# 87                                               persp       FALSE      FALSE
# 453                       agg_inet_billing_transaction       FALSE      FALSE
# 58                                        axc_us_users       FALSE      FALSE
# 136                                     elm_new_worker       FALSE      FALSE
# 103                                        aud_det_seg       FALSE      FALSE
# 48                                        axc_us_posts       FALSE      FALSE
# 110                       fact_sf_b2c_contact_verbatim       FALSE      FALSE
# 392                                                n/a       FALSE      FALSE
# 591              sub_clickstream_tt_start_first_global       FALSE      FALSE
# 294                    src_braze_turbotax_canvas_entry       FALSE      FALSE
# 382              src_sw_agent_schedule_preference_temp       FALSE      FALSE
# 648                              src_ttl_retail_revoke       FALSE      FALSE
# 106                                fact_sf_b2c_contact       FALSE      FALSE
# 62                                  axc_ca_communities       FALSE      FALSE
# 465                      src_inet_dim_interaction_dtmf       FALSE      FALSE
# 46                                  axc_us_communities       FALSE      FALSE
# 439                          rpt_care_cct_interactions       FALSE      FALSE
# 456                           src_inet_dim_call_result       FALSE      FALSE
# 348             idp_ml_casepop_question_classification       FALSE      FALSE
# 387                                    cto_prod_survey       FALSE      FALSE
# 269                 src_braze_mint_behaviors_uninstall       FALSE      FALSE
# 268               src_braze_mint_behaviors_statechange       FALSE      FALSE
# 320                             dim_sales_order_status       FALSE      FALSE
# 638                              src_efe_non_rt_orders       FALSE      FALSE
# 114                                   content_metadata       FALSE      FALSE
# 609                        src_responsys_turbotax_sent       FALSE      FALSE
# 491       tax_rpt.monetization_analytics_master_ytd_vw       FALSE      FALSE
# 116                                 fact_sf_b2c_refund       FALSE      FALSE
# 506                                  w2_auth_base_ty19       FALSE      FALSE
# 64                                        axc_ca_posts       FALSE      FALSE
# 102                                        aud_gen_seg       FALSE      FALSE
# 278                          src_braze_mint_email_send       FALSE      FALSE
# 301                src_braze_turbotax_email_softbounce       FALSE      FALSE
# 57                                       axc_us_topics       FALSE      FALSE
# 471                 src_inet_dim_interaction_sentiment       FALSE      FALSE
#
#         Sync Type                  Status  \
# 593  Column Level
# 610  Column Level
# 322  Column Level
# 90   Column Level
# 715  Column Level
# 378  Column Level
# 432  Column Level
# 480  Column Level
# 293  Column Level
# 584  Column Level
# 111  Column Level
# 455  Column Level
# 586  Column Level
# 60   Column Level
# 61   Column Level
# 87   Column Level
# 453  Column Level
# 58   Column Level
# 136  Column Level
# 103  Column Level
# 48   Column Level
# 110  Column Level
# 392  Column Level
# 591  Column Level
# 294  Column Level
# 382  Column Level
# 648  Column Level
# 106  Column Level
# 62   Column Level
# 465  Column Level
# 46   Column Level
# 439  Column Level
# 456  Column Level
# 348  Column Level
# 387  Column Level
# 269  Column Level  Confirm with Mint Team
# 268  Column Level  Confirm with Mint Team
# 320  Column Level            Out of scope
# 638  Column Level
# 114  Column Level
# 609  Column Level
# 491  Column Level
# 116  Column Level
# 506  Column Level
# 64   Column Level
# 102  Column Level
# 278  Column Level  Confirm with Mint Team
# 301  Column Level
# 57   Column Level
# 471  Column Level
#
#                                                    key  same_table_name
# 593  ctg_analytics.sub_clickstream_visitor_nonffa_f...            False
# 610  ctg_analytics_secure_src.trn_responsys_tt_skipped            False
# 322        consumer_source.src_document_service_expert            False
# 90                          care_dwh.dim_ewfm_seg_code            False
# 715                        mint_dwh.transaction_bankcc            False
# 378     consumer_source.src_snap_qbse_total_subs_daily            False
# 432                       ctg_analyst_layer.cases_uids            False
# 480        ctg_analyst_layer.inet_turbotax_api_details            False
# 293  consumer_source.src_braze_turbotax_users_canva...            False
# 584                  ctg_analytics.lkp_item_alias_rank            False
# 111                    care_dwh.fact_cc_source_mapping            False
# 455    ctg_analyst_layer.inet_dim_billing_transactions            False
# 586               ctg_analytics.sub_auth_id_multifiler            False
# 60                       care_dwh.axc_analytics_events            False
# 61                              care_dwh.axc_bookmarks            False
# 87                             care_dwh.dim_ewfm_persp            False
# 453    ctg_analyst_layer.inet_agg_billing_transactions            False
# 58                                  care_dwh.axc_users            False
# 136                             care_dwh.sf_new_worker            False
# 103                              care_dwh.ewfm_det_seg            False
# 48                                  care_dwh.axc_posts            False
# 110                  care_dwh.fact_cc_contact_verbatim            False
# 392                     cs_dwh.alert_credit_monitoring            False
# 591       ctg_analytics.sub_clickstream_tt_start_first            False
# 294  consumer_source.src_braze_turbotax_users_canva...            False
# 382   consumer_source.src_sw_agent_schedule_preference            False
# 648                         matt_dwh.ttl_retail_revoke            False
# 106                           care_dwh.fact_cc_contact            False
# 62                            care_dwh.axc_communities            False
# 465        ctg_analyst_layer.inet_dim_interaction_dtmf            False
# 46                            care_dwh.axc_communities            False
# 439        ctg_analyst_layer.ctg_care_cct_interactions            False
# 456             ctg_analyst_layer.inet_dim_call_result            False
# 348  consumer_source.src_mxs_idp_ml_casepop_questio...            False
# 387         consumer_source.src_thrive_cto_prod_survey            False
# 269  consumer_source.src_braze_mint_users_behaviors...            False
# 268  consumer_source.src_braze_mint_users_behaviors...            False
# 320       consumer_source.src_cvdim_sales_order_status            False
# 638                                matt_dwh.etx_orders            False
# 114                  care_dwh.fact_cg_content_metadata            False
# 609     ctg_analytics_secure_src.trn_responsys_tt_sent            False
# 491  ctg_analyst_layer.monetization_analytics_maste...            False
# 116                              care_dwh.fact_refunds            False
# 506                     ctg_analyst_layer.w2_auth_base            False
# 64                                  care_dwh.axc_posts            False
# 102                          care_dwh.ewfm_aud_gen_seg            False
# 278  consumer_source.src_braze_mint_users_messages_...            False
# 301  consumer_source.src_braze_turbotax_users_messa...            False
# 57                                 care_dwh.axc_topics            False
# 471   ctg_analyst_layer.inet_dim_interaction_sentiment            False

# %% [markdown]
# #### Read vertica descriptions

# %%
df_vertica_data = read_gsheet(vertica_workbook, VERTICA_SHEET)

df_vertica_data.shape
# Out:
# (5137, 8)

# %%
df_vertica_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5137 entries, 0 to 5136
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   key          5137 non-null   object
#  1   schema       5137 non-null   object
#  2   table        5137 non-null   object
#  3   column       5137 non-null   object
#  4   title        5137 non-null   object
#  5   description  5137 non-null   object
#  6   tag          5137 non-null   object
#  7   data file    5137 non-null   object
# dtypes: object(8)
# memory usage: 321.2+ KB

# %%
# remove tag = exclude - indicator that not the preferred description for rows with multiple descriptions
df_vertica_data = df_vertica_data[df_vertica_data['tag'] != 'exclude']
df_vertica_data.shape
# Out:
# (5103, 8)

# %%
# remove descriptions listed in description exception 
df_vertica_data = df_vertica_data[df_vertica_data['description'].isin(VERTICA_DESC_EXCEPTIONS) == False]
df_vertica_data.shape
# Out:
# (4411, 8)

# %%
df_vertica_data['desc_length'] = df_vertica_data['description'].str.len()

# %%
# df_vertica_data.sample(15)

# %% [markdown]
# #### Create unique list of Vertica column descriptions

# %%
df_vertica_column_desc = df_vertica_data[df_vertica_data['column'] != ""][['key','column','title','description','tag','desc_length']]

df_vertica_column_desc.sort_values(by='column', ascending = True, inplace=True)
df_vertica_column_desc.sort_values(by='desc_length', ascending = False, inplace=True)

df_vertica_column_desc
# Out:
#                                                     key  \
# 3492                   care_dwh.fact_sf_case.segment__c
# 3491                   care_dwh.fact_sf_case.segment__c
# 3528                 care_dwh.fact_sf_case.service_type
# 3527                 care_dwh.fact_sf_case.service_type
# 1690  ctg_analytics_ws.agg_taxml_ytd.flag_disabled_o...
# ...                                                 ...
# 4161  ctg_analytics_ws.schc_tax_profile_ty20_7216.tr...
# 3458  ctg_analytics_ws.schc_tax_profile_ty20_7216.se...
# 1257     ctg_analyst_layer.ctg_care_cct_interactions.dt
# 1138   ctg_analyst_layer.agent_details_proficiency.date
# 1137               ctg_analyst_layer.agent_details.date
#
#                       column                       title  \
# 3492              segment__c
# 3491              segment__c
# 3528            service_type                Type of call
# 3527            service_type                Type of call
# 1690  flag_disabled_or_blind  Flag Disabled Origin Blind
# ...                      ...                         ...
# 4161                  travel                      Travel
# 3458                  se_tax                      se_tax
# 1257                      dt                        Date
# 1138                    date                        Date
# 1137                    date                        Date
#
#                                             description  tag  desc_length
# 3492  <table border="0" cellpadding="0" cellspacing=...  N/A         3598
# 3491  <table border="0" cellpadding="0" cellspacing=...  N/A         3598
# 3528   <table border="0" cellpadding="0" cellspacing...  N/A         1563
# 3527   <table border="0" cellpadding="0" cellspacing...  N/A         1563
# 1690   As a person with a disability, you may qualif...  N/A         1519
# ...                                                 ...  ...          ...
# 4161                                             Travel  N/A            6
# 3458                                             se_tax  N/A            6
# 1257                                               Date  N/A            4
# 1138                                               Date  N/A            4
# 1137                                               Date  N/A            4
#
# [4230 rows x 6 columns]

# %%
column_keyword_list = list(df_vertica_column_desc['column'].value_counts().sort_index().index) 
column_single_keyword_list = []
column_short_single_keyword_list = []

for c in column_keyword_list:
    if c.find("_") == -1:
        column_single_keyword_list.append(c)
        
for c in column_single_keyword_list:
    if len(c) <= 10:
        column_short_single_keyword_list.append(c)
        
print(f"Keyword list count:   {len(column_keyword_list)}")
print(f"Single keyword count: {len(column_single_keyword_list)}")
print(f"Short keyword count:  {len(column_short_single_keyword_list)}")
print("")
print(column_short_single_keyword_list)
# Out:
# Keyword list count:   2539
# Single keyword count: 303
# Short keyword count:  252
#
# ['address', 'address2', 'agi', 'aht', 'alliance', 'amount', 'ani', 'authid', 'bu', 'business', 'cancelled', 'cardtype', 'caseid', 'casenumber', 'channel', 'checksum', 'childcare', 'cid', 'cid1', 'cid2', 'cid3', 'cid4', 'cid5', 'cid6', 'cid7', 'cid8', 'city', 'client', 'cmc', 'company', 'con', 'country', 'createdate', 'cypy', 'date', 'day', 'defected', 'definition', 'deleted', 'desktop', 'details', 'direction', 'dnis', 'domain', 'downvotes', 'dt', 'edition', 'effort', 'ein', 'email', 'email1', 'email2', 'email3', 'estore', 'ethnicity', 'evar01', 'evar02', 'evar03', 'evar04', 'evar05', 'evar06', 'evar07', 'evar08', 'evar09', 'evar10', 'evar11', 'evar12', 'evar13', 'evar14', 'evar15', 'evar16', 'evar17', 'evar18', 'evar19', 'evar20', 'evar21', 'evar22', 'evar23', 'evar24', 'evar25', 'evar26', 'evar27', 'evar28', 'evar29', 'evar30', 'evar31', 'evar32', 'evar33', 'evar34', 'evar35', 'evar36', 'evar37', 'evar38', 'evar39', 'evar40', 'evar41', 'evar42', 'evar43', 'evar44', 'evar45', 'evar46', 'evar47', 'evar48', 'evar49', 'evar50', 'eventid', 'extension', 'farmincome', 'feedback', 'fy', 'gender', 'gotmarried', 'guid', 'hadjob', 'hier1', 'hier2', 'hier3', 'hier4', 'hier5', 'homepage', 'host', 'hour', 'id', 'intent', 'interest', 'intuittid', 'ip', 'ivid', 'location', 'model', 'modelname', 'month', 'mortgage', 'moved', 'name', 'node', 'nodoubt', 'operation', 'origin', 'pagename', 'partner', 'phone', 'platform', 'plugins', 'port', 'postdate', 'posters', 'posts', 'priority', 'product', 'profile', 'prop01', 'prop02', 'prop03', 'prop04', 'prop05', 'prop06', 'prop07', 'prop08', 'prop09', 'prop10', 'prop11', 'prop12', 'prop13', 'prop14', 'prop15', 'prop16', 'prop17', 'prop18', 'prop19', 'prop20', 'prop21', 'prop22', 'prop23', 'prop24', 'prop25', 'prop26', 'prop27', 'prop28', 'prop29', 'prop30', 'prop31', 'prop32', 'prop33', 'prop34', 'prop35', 'prop36', 'prop37', 'prop38', 'prop39', 'prop40', 'prop41', 'prop42', 'prop43', 'prop44', 'prop45', 'prop46', 'prop47', 'prop48', 'prop49', 'prop50', 'protocol', 'purchaseid', 'query', 'race', 'realmid', 'reason', 'recipe', 'referrer', 'reply', 'retailer', 'retained', 'role', 'score', 'segment', 'service', 'site', 'sku', 'soldahome', 'source', 'sourceform', 'ssn', 'state', 'status', 'subject', 'subvenue', 'succeeded', 'supplies', 'survey', 'tid', 'time', 'topic', 'trainer', 'transamt', 'transdate', 'travel', 'trialstart', 'turnaways', 'ty', 'type', 'updatedate', 'upvotes', 'userid', 'uuid', 'vendor', 'venue', 'version', 'visid', 'workgroup', 'year', 'zip', 'zipcode']

# %%
df_vertica_column_desc.shape
# Out:
# (4230, 6)

# %%
# prior to removing duplicates
# print(df_vertica_column_desc[['column','desc_length']].groupby('column').max().head(50))
# print(df_vertica_column_desc[['column','desc_length']].groupby('column').count().head(50))

# %%
df_vertica_column_desc.duplicated(subset=['column']).sum()
# Out:
# 1691

# %%
df_vertica_column_desc.drop_duplicates(subset=['column'],inplace=True)
df_vertica_column_desc.shape
# Out:
# (2539, 6)

# %%
# cleaned-up of duplicates
# print(df_vertica_column_desc[['column','desc_length']].groupby('column').max().head(50))
# print(df_vertica_column_desc[['column','desc_length']].groupby('column').count().head(50))

# %%
df_vertica_column_desc.sort_values(by='column', ascending = True, inplace=True)
df_vertica_column_desc.reset_index
df_vertica_column_desc.head()
# Out:
#                                                  key                  column  \
# 0          ctg_analytics.fact_clickstream.ab_test_id              ab_test_id
# 1          care_dwh.fact_cc_standardized.abandon_flg             abandon_flg
# 4  ctg_analyst_layer.ctg_care_cct_interactions_vw...           abandoned_flg
# 6                 care_dwh.ewfm_cap_plan.abn_percent             abn_percent
# 7  ctg_analytics_ws.agg_taxml_ytd.aca_full_year_c...  aca_full_year_coverage
#
#                     title                                        description  \
# 0        Ab Test Identify  the Auth interaction with the product is a par...
# 1            Abandon Flag  1 or 0 to indicate if a contact that made it t...
# 4          Abandoned Flag  Indicates if a call was abandoned by the custo...
# 6                          Percentage of calls not handled in the indicat...
# 7  ACA Full Year Coverage  ACA Flag if you the user have the coverage for...
#
#    tag  desc_length
# 0  N/A          141
# 1  N/A          347
# 4  N/A           71
# 6  N/A           58
# 7  N/A          248

# %% [markdown]
# #### Create a unique list of Vertica table description

# %%
df_vertica_table_desc = df_vertica_data[(df_vertica_data['column'] == "") & ((df_vertica_data['table'] != "")) ][['key','table','title','description','tag','desc_length']]

df_vertica_table_desc.sort_values(by='table', ascending = True, inplace=True)
df_vertica_table_desc.sort_values(by='desc_length', ascending = False, inplace=True)

df_vertica_table_desc
# Out:
#                                                   key  \
# 4955      ctg_analyst_layer.agent_details_proficiency
# 5115           tax_published.ty20_full_service_master
# 5039               ctg_analytics.fact_taxprep_session
# 4976             ctg_analyst_layer.ctg_care_cases_voc
# 4978   ctg_analyst_layer.ctg_care_cct_interactions_vw
# ...                                               ...
# 5095  ctg_analyst_layer.testing_analytics_master_auth
# 4986             ctg_analytics_ws.cy_turbo_cmc_master
# 4957        ctg_analyst_layer.agent_proficiency_total
# 5081                 consumer_source.src_pq_applicant
# 4985                   ctg_analytics_ws.cy_cmc_master
#
#                               table                             title  \
# 4955      agent_details_proficiency         Agent Details Proficiency
# 5115       ty20_full_service_master       Type 20 Full Service Master
# 5039           fact_taxprep_session
# 4976             ctg_care_cases_voc  Case Surveys and Verbatims Table
# 4978   ctg_care_cct_interactions_vw
# ...                             ...                               ...
# 5095  testing_analytics_master_auth     Testing Analytics Master Auth
# 4986            cy_turbo_cmc_master               Turbo EM CMC Master
# 4957        agent_proficiency_total           Agent Proficiency Total
# 5081               src_pq_applicant          Source Prequal Applicant
# 4985                  cy_cmc_master                  TT EM CMC Master
#
#                                             description  \
# 4955   The agent details proficiency query is the pr...
# 5115   <strong><u>Table Description: </u></strong> 1...
# 5039   SOURCE: MATT \n\nThis table is meant to repre...
# 4976   <u>Github link</u> <a href="https://github.in...
# 4978   ININ and Amazon Connect calls/interactions wi...
# ...                                                 ...
# 5095                      Testing Analytics Master Auth
# 4986                          List of all Turbo EM CMC.
# 4957                            Agent Proficiency Total
# 5081                             Prequal applicant data
# 4985                             TT EM CMC master list.
#
#                                            tag  desc_length
# 4955                                      null         1427
# 5115                                      null          948
# 5039  ["compliance.ccpa", "product.turbo_tax"]          874
# 4976  ["compliance.ccpa", "product.turbo_tax"]          820
# 4978                                      null          722
# ...                                        ...          ...
# 5095                                      null           29
# 4986                                      null           25
# 4957                                      null           23
# 5081                                      null           22
# 4985                                      null           22
#
# [160 rows x 6 columns]

# %%
df_vertica_table_desc.shape
# Out:
# (160, 6)

# %%
# df_vertica_table_desc.head(50)

# %%
df_vertica_table_desc.duplicated(subset=['table']).sum()
# Out:
# 25

# %%
df_vertica_table_desc.drop_duplicates(subset=['table'],inplace=True)
df_vertica_table_desc.shape
# Out:
# (135, 6)

# %%
df_vertica_table_desc.sort_values(by='table', ascending = True, inplace=True)
df_vertica_table_desc.reset_index
df_vertica_table_desc.head()
# Out:
#                                                  key  \
# 4954                 care_dwh.agent_auth_corp_id_map
# 4955     ctg_analyst_layer.agent_details_proficiency
# 4956  ctg_analyst_layer.agent_proficiency_exp_levels
# 4957       ctg_analyst_layer.agent_proficiency_total
# 4958      ctg_analytics_ws.agg_auth_id_sku_selection
#
#                              table  \
# 4954        agent_auth_corp_id_map
# 4955     agent_details_proficiency
# 4956  agent_proficiency_exp_levels
# 4957       agent_proficiency_total
# 4958     agg_auth_id_sku_selection
#
#                                                   title  \
# 4954  Agent authentication id and corp id mapping table
# 4955                          Agent Details Proficiency
# 4956                                  Agent Proficiency
# 4957                            Agent Proficiency Total
# 4958                 Aggreg Auth Identify Sku Selection
#
#                                             description  \
# 4954  This table contains the mapping of agents corp...
# 4955   The agent details proficiency query is the pr...
# 4956          Agent Proficiency Measured by Call Volume
# 4957                            Agent Proficiency Total
# 4958  aggregate table that summarizes where users ch...
#
#                                            tag  desc_length
# 4954  ["compliance.ccpa", "product.turbo_tax"]          270
# 4955                                      null         1427
# 4956                                      null           41
# 4957                                      null           23
# 4958  ["compliance.ccpa", "product.turbo_tax"]          166

# %% [markdown]
# ### read in Alation current data lake catalog
#
# From latest Alation data catalog export

# %%
source_files = []

for f in os.listdir(CATALOG_LOCAL_PATH):
    if f[-3:] == "csv":
        source_files.append(f)
        
print(source_files)
# Out:
# ['bud_clickstream_dwh_schema_19990_2104_2022-03-29T15-39-25-899169.csv', 'bup_dm_schema_20306_2104_2022-03-29T15-40-05-454383.csv', 'bup_src_schema_20307_2104_2022-03-29T15-43-51-419732.csv', 'cgdata_taxml_dwh_schema_16407_2104_2022-03-29T15-40-50-541437.csv', 'common_dm_schema_20479_2104_2022-03-29T15-45-32-002211.csv', 'ixp_dwh_schema_16459_2104_2022-03-29T15-44-58-163604.csv', 'smartmoney_dm_schema_19722_2104_2022-03-29T15-49-03-626123.csv', 'smartmoney_src_schema_20123_2104_2022-03-29T15-50-50-984401.csv', 'tax_dm_schema_19392_2104_2022-03-29T15-49-40-053659.csv', 'tax_rpt_schema_19891_2104_2022-03-29T15-54-20-533275.csv', 'tax_src_schema_19460_2104_2022-03-29T15-52-13-842602.csv', 'thrive_dwh_7216_restricted_schema_15534_2104_2022-03-29T16-00-26-992931.csv', 'thrive_dwh_schema_1551_2104_2022-03-29T16-06-46-408881.csv', 'ued_creditscore_dwh_schema_15280_2104_2022-03-29T16-01-57-526424.csv', 'ued_mint_dwh_schema_18258_2104_2022-03-29T16-02-44-977558.csv']

# %%
# create empty data frame 
df_alation_catalog = pd.DataFrame( 
                columns = ['key','title', 'description','steward:user','intuit_classification',
                           'schema','table','column','needs_description'])

df_alation_catalog['needs_description'] = df_alation_catalog['needs_description'].astype('bool')

df_alation_catalog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   key                    0 non-null      object
#  1   title                  0 non-null      object
#  2   description            0 non-null      object
#  3   steward:user           0 non-null      object
#  4   intuit_classification  0 non-null      object
#  5   schema                 0 non-null      object
#  6   table                  0 non-null      object
#  7   column                 0 non-null      object
#  8   needs_description      0 non-null      bool
# dtypes: bool(1), object(8)
# memory usage: 0.0+ bytes

# %%
# create Alation current catalog data frame
for f in source_files:
    # read catalog data file 
    source_file = os.path.join(CATALOG_LOCAL_PATH, f)
    
    df_temp = pd.read_csv(source_file,  usecols=['key','title','description','steward:user','intuit_classification'])
        
    key_values = df_temp['key'].tolist()

    # break out key into individual elements
    schema_names = []
    table_names = []
    column_names = []

    for i in range(0,len(key_values)):
        key_elements = key_values[i].split(".")

        schema_names.append(key_elements[0])
        if len(key_elements) >= 2:
            table_names.append(key_elements[1])
        else:
            table_names.append("")
        if len(key_elements) >= 3:
            column_names.append(key_elements[2])
        else:
            column_names.append("")

    df_temp['schema'] = schema_names
    df_temp['table'] = table_names
    df_temp['column'] = column_names
    
    # add needs description bolean
    df_temp['needs_description'] = df_temp['description'].isnull() 
    
    df_alation_catalog = pd.concat([df_alation_catalog, df_temp], ignore_index=True, sort=False)
    
df_alation_catalog.shape
# Out:
# (62763, 9)

# %%
df_alation_catalog[['key','schema','table','column','description']].sample(20)
# Out:
#                                                      key  \
# 32714  tax_src.src_taxml_historical.k1pw_rental_activ...
# 26913            tax_rpt.agg_user_care_case.max_datetime
# 19032  tax_dm.agg_auth_id_revenue.total_audit_defense...
# 59256                          ued_mint_dwh.form.mfatype
# 23987  tax_rpt.agent_details_51346.nbr_auto_closed_cases
# 59376    ued_mint_dwh.credit_profile_ingest.creationtime
# 36561        tax_src.src_fdp_document_service_event.year
# 50678       thrive_dwh.cto_fdp_widget_service.providerid
# 18590  tax_dm.fact_financial_events.last_credit_card_...
# 55294  thrive_dwh.cg_turbotax_clickstream.sibling_eve...
# 62177  ued_mint_dwh.credit_inquiry_delete.inquirerind...
# 14293  smartmoney_dm.transaction_bankcc_redshift.yodt...
# 56620  ued_credit_score_dwh.credit_alert_notification...
# 6560          cgdata_taxml_dwh.taxml.amount_capital_gain
# 3834   bud_clickstream_dwh.ecs_clickstream_turbotax_t...
# 57732         ued_mint_dwh.account_loan_delete.yodlender
# 46191  thrive_dwh.sbseg_clickstream_web_test.post_geo...
# 2024   bud_clickstream_dwh.ecs_clickstream_turbotax_t...
# 18100  tax_dm.v_marketing_first_party_attribute.prior...
# 46095  thrive_dwh.cg_turbotax_clickstream_test.search...
#
#                      schema                               table  \
# 32714               tax_src                src_taxml_historical
# 26913               tax_rpt                  agg_user_care_case
# 19032                tax_dm                 agg_auth_id_revenue
# 59256          ued_mint_dwh                                form
# 23987               tax_rpt                 agent_details_51346
# 59376          ued_mint_dwh               credit_profile_ingest
# 36561               tax_src      src_fdp_document_service_event
# 50678            thrive_dwh              cto_fdp_widget_service
# 18590                tax_dm               fact_financial_events
# 55294            thrive_dwh             cg_turbotax_clickstream
# 62177          ued_mint_dwh               credit_inquiry_delete
# 14293         smartmoney_dm         transaction_bankcc_redshift
# 56620  ued_credit_score_dwh    credit_alert_notification_delete
# 6560       cgdata_taxml_dwh                               taxml
# 3834    bud_clickstream_dwh     ecs_clickstream_turbotax_ty2021
# 57732          ued_mint_dwh                 account_loan_delete
# 46191            thrive_dwh          sbseg_clickstream_web_test
# 2024    bud_clickstream_dwh  ecs_clickstream_turbotax_ty2021_v3
# 18100                tax_dm   v_marketing_first_party_attribute
# 46095            thrive_dwh        cg_turbotax_clickstream_test
#
#                                                   column  \
# 32714                  k1pw_rental_actively_participated
# 26913                                       max_datetime
# 19032                        total_audit_defense_revenue
# 59256                                            mfatype
# 23987                              nbr_auto_closed_cases
# 59376                                       creationtime
# 36561                                               year
# 50678                                         providerid
# 18590               last_credit_card_account_opened_date
# 55294                      sibling_event_sender_versions
# 62177                                   inquirerindustry
# 14293                               yodtransactionstatus
# 56620                                       trackinguuid
# 6560                                 amount_capital_gain
# 3834                               properties_lead_email
# 57732                                          yodlender
# 46191                          post_geo_isp_organization
# 2024   properties_app_context_top_level_tracking_cont...
# 18100                          prioryearistwoplusdevices
# 46095                              search_module_details
#
#                                              description
# 32714                                                NaN
# 26913                                                NaN
# 19032  <p>It is the revenue  when the customer attach...
# 59256                                                NaN
# 23987                                                NaN
# 59376                                                NaN
# 36561                                                NaN
# 50678                                                NaN
# 18590                                                NaN
# 55294  <p>Sibling Event Sender Versions -- where 'sib...
# 62177                                                NaN
# 14293  <p>Yodlee  status of the transaction: PENDING ...
# 56620                                                NaN
# 6560   <div><hr><p>Cascaded below fields from : <a da...
# 3834                                                 NaN
# 57732                                                NaN
# 46191                                                NaN
# 2024                                                 NaN
# 18100                                                NaN
# 46095                                                NaN

# %%
# filter out data frame to retain columns that need a description
df_alation_catalog = df_alation_catalog[(df_alation_catalog['needs_description']) & (df_alation_catalog['column'] != "")]

df_alation_catalog.shape
# Out:
# (51938, 9)

# %%
# remove columns with names in short names list 
df_alation_catalog = df_alation_catalog[df_alation_catalog['column'].isin(column_short_single_keyword_list) == False]
df_alation_catalog.shape
# Out:
# (48443, 9)

# %%
df_alation_catalog[['key','schema','table','column','description']].sample(20)
# Out:
#                                                      key               schema  \
# 76     bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 11206         cgdata_taxml_dwh.taxml_bkp.stinfotp_felona     cgdata_taxml_dwh
# 46167  thrive_dwh.cg_turbotax_clickstream_test.top_ev...           thrive_dwh
# 10300  cgdata_taxml_dwh.taxml_delete_27thjan_bk.amoun...     cgdata_taxml_dwh
# 51795  thrive_dwh.fdp_mint_global_clickstream_mobile....           thrive_dwh
# 24863  tax_rpt.product_analytics_master_parity.start_...              tax_rpt
# 56118  thrive_dwh.cto_fdp_credential_offering_intent....           thrive_dwh
# 28432               tax_src.src_taxml.amount_taxable_ira              tax_src
# 8343        cgdata_taxml_dwh.taxml_delete.stinfodp_qaocn     cgdata_taxml_dwh
# 25730  tax_rpt.rpt_testing_analytics_master_auth2.mon...              tax_rpt
# 6452             bup_src.src_pplat_offer_dismiss.hive_ts              bup_src
# 7502        cgdata_taxml_dwh.taxml_ingest.bus_cogs_labor     cgdata_taxml_dwh
# 58027                    ued_mint_dwh.account.linkstatus         ued_mint_dwh
# 53639  thrive_dwh.cg_c360_aamsegment_model.ty19resona...           thrive_dwh
# 3656   bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 33877         tax_src.src_kochava_event.kochava_click_id              tax_src
# 19015  tax_dm.fact_financial_events.first_tire_dealer...               tax_dm
# 45790         thrive_dwh.cto_fdp_transaction_test.extra6           thrive_dwh
# 1230   bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 12551   ixp_dwh.ixp_mis_match_check.assignment_timestamp              ixp_dwh
#
#                                     table  \
# 76     ecs_clickstream_turbotax_ty2021_v4
# 11206                           taxml_bkp
# 46167        cg_turbotax_clickstream_test
# 10300             taxml_delete_27thjan_bk
# 51795  fdp_mint_global_clickstream_mobile
# 24863     product_analytics_master_parity
# 56118  cto_fdp_credential_offering_intent
# 28432                           src_taxml
# 8343                         taxml_delete
# 25730  rpt_testing_analytics_master_auth2
# 6452              src_pplat_offer_dismiss
# 7502                         taxml_ingest
# 58027                             account
# 53639            cg_c360_aamsegment_model
# 3656      ecs_clickstream_turbotax_ty2021
# 33877                   src_kochava_event
# 19015               fact_financial_events
# 45790            cto_fdp_transaction_test
# 1230   ecs_clickstream_turbotax_ty2020_v3
# 12551                 ixp_mis_match_check
#
#                                              column description
# 76                properties_custom_cf_action_value         NaN
# 11206                               stinfotp_felona         NaN
# 46167                        top_event_sender_alias         NaN
# 10300                          amount_other_credits         NaN
# 51795                       post_first_hit_pagename         NaN
# 24863                           start_sku_rollup_id         NaN
# 56118                                hive_timestamp         NaN
# 28432                            amount_taxable_ira         NaN
# 8343                                 stinfodp_qaocn         NaN
# 25730                  monetization_take_max_upsell         NaN
# 6452                                        hive_ts         NaN
# 7502                                 bus_cogs_labor         NaN
# 58027                                    linkstatus         NaN
# 53639  ty19resonatehelpsreachfinancialgoalsdisagree         NaN
# 3656                                     context_ip         NaN
# 33877                              kochava_click_id         NaN
# 19015                first_tire_dealer_inquiry_date         NaN
# 45790                                        extra6         NaN
# 1230          properties_custom_video_onload_height         NaN
# 12551                          assignment_timestamp         NaN

# %% [markdown]
# ### Prepare new definition data set
#
# Merge alation catalog with vertica data frames

# %%
# create empty target data frame 
df_new_definitions = pd.DataFrame( 
                columns = ['key','schema','title','description','steward:user','intuit_classification'])

df_new_definitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   key                    0 non-null      object
#  1   schema                 0 non-null      object
#  2   title                  0 non-null      object
#  3   description            0 non-null      object
#  4   steward:user           0 non-null      object
#  5   intuit_classification  0 non-null      object
# dtypes: object(6)
# memory usage: 0.0+ bytes

# %% [markdown]
# #### Merge Vertica Column Definitions

# %%
# print(df_alation_catalog.info())
# print(df_vertica_column_desc.info())

# %%
# merge alation catalog and vertica descriptions on column name
df_col_definitions = pd.merge(df_alation_catalog[['column','schema','key','title','steward:user','intuit_classification']], 
                        df_vertica_column_desc[['column','title','description']], on='column')

df_col_definitions.rename(columns={'title_x':'title'}, inplace=True)  

df_col_definitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9141 entries, 0 to 9140
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   column                 9141 non-null   object
#  1   schema                 9141 non-null   object
#  2   key                    9141 non-null   object
#  3   title                  7754 non-null   object
#  4   steward:user           0 non-null      object
#  5   intuit_classification  86 non-null     object
#  6   title_y                9141 non-null   object
#  7   description            9141 non-null   object
# dtypes: object(8)
# memory usage: 642.7+ KB

# %%
df_col_definitions['title'].isna().sum()
# Out:
# 1387

# %%
df_col_definitions.fillna(value={'title': df_col_definitions['title_y']}, inplace=True)

# %%
df_col_definitions['title'].isna().sum()
# Out:
# 0

# %%
df_col_definitions[['column','title','title_y']].sample(15)
# Out:
#                                column  \
# 4163                      offered_flg
# 9                            tax_year
# 2617                  spouse_military
# 2231               amount_taxable_ira
# 383                 dwh_creation_time
# 6815                     site_area_id
# 6011               first_session_flag
# 2198                    address_state
# 6853                         trans_id
# 799                       ingest_date
# 6185                total_max_revenue
# 6866  monetization_see_max_ryo_upsell
# 447                    event_datetime
# 6054                      device_type
# 5310               training_class_key
#
#                                               title  \
# 4163                                   Offered Flag
# 9                                          Tax Year
# 2617                                Spouse Military
# 2231                             Amount Taxable Ira
# 383                    Data Warehouse Creation Time
# 6815                             Site Area Identify
# 6011                             First Session Flag
# 2198                                  Address State
# 6853                                       TRANS_ID
# 799                                     Ingest Date
# 6185                              Total Max Revenue
# 6866  Monetization See Max Review Your Order Upsell
# 447                                  Event Datetime
# 6054                                    Device Type
# 5310                             Training Class Key
#
#                                             title_y
# 4163                                   Offered Flag
# 9                                          Tax Year
# 2617                                Spouse Military
# 2231                             Amount Taxable Ira
# 383                               Dwh Creation Time
# 6815                             Site Area Identify
# 6011                             First Session Flag
# 2198                                  Address State
# 6853                                       TRANS_ID
# 799                                     Ingest Date
# 6185                              TOTAL_MAX_REVENUE
# 6866  Monetization See Max Review Your Order Upsell
# 447                                  event_datetime
# 6054                                    Device Type
# 5310                             Training Class Key

# %%
df_new_definitions = pd.concat([df_new_definitions, 
                               df_col_definitions[['key','schema','title','description','steward:user','intuit_classification']]], 
                               ignore_index = True)

# %%
df_new_definitions.fillna(value={'steward:user': ''}, inplace=True)
df_new_definitions.fillna(value={'intuit_classification': 'restricted'}, inplace=True)

df_new_definitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9141 entries, 0 to 9140
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   key                    9141 non-null   object
#  1   schema                 9141 non-null   object
#  2   title                  9141 non-null   object
#  3   description            9141 non-null   object
#  4   steward:user           9141 non-null   object
#  5   intuit_classification  9141 non-null   object
# dtypes: object(6)
# memory usage: 428.6+ KB

# %% [markdown]
# #### Merge Vertica Table Definitions

# %%
print(df_alation_catalog.info())
print(df_dl_map.info())
print(df_vertica_table_desc.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48443 entries, 15 to 62762
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   key                    48443 non-null  object
#  1   title                  34571 non-null  object
#  2   description            0 non-null      object
#  3   steward:user           2 non-null      object
#  4   intuit_classification  431 non-null    object
#  5   schema                 48443 non-null  object
#  6   table                  48443 non-null  object
#  7   column                 48443 non-null  object
#  8   needs_description      48443 non-null  bool
# dtypes: bool(1), object(8)
# memory usage: 3.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 338 entries, 33 to 794
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CTG Vertica Key         338 non-null    object
#  1   CTG Vertica AWS schema  338 non-null    object
#  2   CTG Vertica AWS table   338 non-null    object
#  3   Data Lake Key           338 non-null    object
#  4   Data Lake Schema        338 non-null    object
#  5   Data Lake Table         338 non-null    object
#  6   Same schema             338 non-null    object
#  7   Same table              338 non-null    object
#  8   Sync Type               338 non-null    object
#  9   Status                  338 non-null    object
#  10  key                     338 non-null    object
#  11  same_table_name         338 non-null    bool
# dtypes: bool(1), object(11)
# memory usage: 32.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135 entries, 4954 to 5115
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   key          135 non-null    object
#  1   table        135 non-null    object
#  2   title        135 non-null    object
#  3   description  135 non-null    object
#  4   tag          135 non-null    object
#  5   desc_length  135 non-null    int64
# dtypes: int64(1), object(5)
# memory usage: 7.4+ KB
# None

# %%
# expand vertica table_desc to data lake table names
# match on vertica table key 
df_vertica_table_extended = pd.merge(df_vertica_table_desc,
                        df_dl_map[['key','CTG Vertica AWS schema','CTG Vertica AWS table',
                                   'Data Lake Key','Data Lake Schema','Data Lake Table']],
                        on='key')

# switch to DL table key 
df_vertica_table_extended['key'] = df_vertica_table_extended['Data Lake Key']

# %%
df_vertica_table_extended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   key                     32 non-null     object
#  1   table                   32 non-null     object
#  2   title                   32 non-null     object
#  3   description             32 non-null     object
#  4   tag                     32 non-null     object
#  5   desc_length             32 non-null     int64
#  6   CTG Vertica AWS schema  32 non-null     object
#  7   CTG Vertica AWS table   32 non-null     object
#  8   Data Lake Key           32 non-null     object
#  9   Data Lake Schema        32 non-null     object
#  10  Data Lake Table         32 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 3.0+ KB

# %%
df_vertica_table_extended.sort_values(by='key', ascending = True, inplace=True)

df_vertica_table_extended.head(32)
# Out:
#                                              key  \
# 13                ent_dwr_dwh.dw_as_standardized
# 16                ent_dwr_dwh.dw_cc_standardized
# 21                         ent_elm_dwh.elm_agent
# 22         ent_elm_dwh.elm_agent_additional_info
# 6              ent_ewfm_tcsdbowner_dwh.acd_login
# 12           ent_ewfm_tcsdbowner_dwh.aud_det_seg
# 7                ent_ewfm_tcsdbowner_dwh.seg_cat
# 8     ent_ewfm_tcsdbowner_dwh.seg_code_cat_assoc
# 9              ent_ewfm_tcsdbowner_dwh.tcs_login
# 10             ent_ewfm_tcsdbowner_dwh.time_zone
# 4   intuit_identity_lifecycle_dwh.person_profile
# 19          ivr_rpt.agg_inet_billing_transaction
# 14             tax_dm.fact_auth_id_sompleted_sku
# 15                    tax_dm.fact_sf_b2c_contact
# 1                     tax_rpt.agg_user_care_case
# 20                tax_rpt.request_uuid_info_ty19
# 3              tax_rpt.rpt_care_cct_interactions
# 0                           tax_rpt.rpt_case_uid
# 2                      tax_rpt.rpt_ctg_care_case
# 18              tax_src.axc_ca_helpful_votes_all
# 17              tax_src.axc_us_helpful_votes_all
# 5                    tax_src.dim_campaign_global
# 11                   tax_src.dim_page_url_global
# 25              tax_src.getdata_form_generic_raw
# 26             tax_src.src_ttl_retail_activation
# 27              tax_src.src_ttl_retail_printfile
# 28                 tax_src.src_ttl_retail_revoke
# 29                tax_src.src_ttl_retail_upgrade
# 30                        tax_src.src_tto_orders
# 31              tax_src.src_tto_sessionstart_log
# 24       tax_src.sub_auth_credit_campaign_global
# 23     tax_ws.src_sw_wfm_schedule_slot_stat_temp
#
#                                    table  \
# 13                  fact_as_standardized
# 16                  fact_cc_standardized
# 21                          sf_alm_agent
# 22          sf_alm_agent_additional_info
# 6                     dim_ewfm_acd_login
# 12                          ewfm_det_seg
# 7                       dim_ewfm_seg_cat
# 8            dim_ewfm_seg_code_cat_assoc
# 9                     dim_ewfm_tcs_login
# 10                    dim_ewfm_time_zone
# 4                       customer_account
# 19         inet_agg_billing_transactions
# 14            fact_auth_id_completed_sku
# 15                       fact_cc_contact
# 1         ctg_care_case_history_user_agg
# 20                     request_uuid_info
# 3              ctg_care_cct_interactions
# 0                             cases_uids
# 2                         ctg_care_cases
# 18                     helpful_votes_all
# 17                     helpful_votes_all
# 5                           dim_campaign
# 11                          dim_page_url
# 25  trn_getdata_form_generic_information
# 26                 ttl_retail_activation
# 27                  ttl_retail_printfile
# 28                     ttl_retail_revoke
# 29                    ttl_retail_upgrade
# 30                            tto_orders
# 31                  tto_sessionstart_log
# 24              sub_auth_credit_campaign
# 23         src_sw_wfm_schedule_slot_stat
#
#                                                title  \
# 13                            Agent States Call Data
# 16
# 21
# 22
# 6                               eWFM ACD Login Table
# 12                              Ewfm Detail Segments
# 7                              eWFM Segment Category
# 8                    ewfm SegCode/SegCat Association
# 9                                    eWFM TCS Logins
# 10                                Dim Ewfm Time Zone
# 4                                   Customer Account
# 19              iNet Aggregated Billing Transactions
# 14                  Fact Auth Identify Completed Sku
# 15                   Factorid Channel Chosen Contact
# 1
# 20                                   W2 Source Table
# 3
# 0
# 2                                     CTG Care Cases
# 18                             Helpfulness Votes All
# 17                             Helpfulness Votes All
# 5                                       Dim Campaign
# 11                                          Page URL
# 25  Transaction table for Get Data (import) attempts
# 26                   Turbotax Live Retail Activation
# 27                    Turbotax Live Retail PrintFile
# 28                       Turbotax Live Retail Revoke
# 29                      Turbotax Live Retail Upgrade
# 30                           Turbo Tax Online Orders
# 31                 Turbo Tax Online SessionStart Log
# 24                          Sub Auth Credit Campaign
# 23
#
#                                           description  \
# 13   Call Data pertaining to Agent States from Ama...
# 16  There are key things to understand about this ...
# 21  WHAT: This table stores agent/pro's profile da...
# 22  WHAT: This table stores agent/pro's profile da...
# 6   Table displaying ACD Logins to EMP_SK values. ...
# 12  Lists segments in an employees Schedule over t...
# 7   Can be combined with the dim_ewfm_seg_code_cat...
# 8   Can be used to join the dim_ewfm_seg_code tabl...
# 9   TCS Login Table - Can be used to associate the...
# 10  Can be used to tell which timezone employees/T...
# 4   Maintains Authenticated customer email , login...
# 19  This table captures the billing records for ea...
# 14  this table maintains the Fed online turbo tax ...
# 15                  Case information from Salesforce
# 1              Summarizes SFDC case ownership changes
# 20  W2 level table containing information on the s...
# 3          ININ and Amazon Connect calls/interactions
# 0   Mapping for SF case to Amazon or ININ call sou...
# 2   SFDC cases data, supplemented with web and oth...
# 18  Table contains all up and down vote direction ...
# 17  Table contains all up and down vote direction ...
# 5   Lookup table that adds new Campaign IDs (CIDs)...
# 11  contains a full list of HTTP referer URL along...
# 25  Table that captures the results of Get Data tr...
# 26  This table contains ttl retail activation logs...
# 27  This table contains ttl retail printfile logs ...
# 28  This table contains ttl retail revoke logs (Tu...
# 29  This table contains ttl retail activation logs...
# 30  This table contains order log events for TTO (...
# 31  This table contains session log events for TTO...
# 24  Table to determine the campaign of credit for ...
# 23   <a href="https://wiki.intuit.com/pages/viewpa...
#
#                                                   tag  desc_length  \
# 13                                               null          313
# 16                                               null          550
# 21                                               null          226
# 22           ["compliance.ccpa", "product.turbo_tax"]          210
# 6                                                null          183
# 12                                               null          234
# 7                                                null          172
# 8                                                null          141
# 9                                                null          167
# 10                                               null          141
# 4   ["compliance.ccpa", "product.turbo", "product....          150
# 19                                               null           75
# 14           ["compliance.ccpa", "product.turbo_tax"]          168
# 15           ["compliance.ccpa", "product.turbo_tax"]           33
# 1                                                null           38
# 20           ["compliance.ccpa", "product.turbo_tax"]          285
# 3            ["compliance.ccpa", "product.turbo_tax"]           42
# 0                                                null          109
# 2            ["compliance.ccpa", "product.turbo_tax"]           54
# 18           ["compliance.ccpa", "product.turbo_tax"]          254
# 17           ["compliance.ccpa", "product.turbo_tax"]          254
# 5                                                null          412
# 11                                               null          100
# 25           ["compliance.ccpa", "product.turbo_tax"]          167
# 26                                               null          343
# 27                                               null          342
# 28                                               null          339
# 29                                               null          343
# 30           ["compliance.ccpa", "product.turbo_tax"]          341
# 31           ["compliance.ccpa", "product.turbo_tax"]          343
# 24           ["compliance.ccpa", "product.turbo_tax"]          314
# 23                                               null          143
#
#    CTG Vertica AWS schema                 CTG Vertica AWS table  \
# 13               care_dwh                  fact_as_standardized
# 16               care_dwh                  fact_cc_standardized
# 21               care_dwh                          sf_alm_agent
# 22               care_dwh          sf_alm_agent_additional_info
# 6                care_dwh                    dim_ewfm_acd_login
# 12               care_dwh                          ewfm_det_seg
# 7                care_dwh                      dim_ewfm_seg_cat
# 8                care_dwh           dim_ewfm_seg_code_cat_assoc
# 9                care_dwh                    dim_ewfm_tcs_login
# 10               care_dwh                    dim_ewfm_time_zone
# 4           matt_comp_dwh                      customer_account
# 19      ctg_analyst_layer         inet_agg_billing_transactions
# 14          ctg_analytics            fact_auth_id_completed_sku
# 15               care_dwh                       fact_cc_contact
# 1       ctg_analyst_layer        ctg_care_case_history_user_agg
# 20      ctg_analyst_layer                     request_uuid_info
# 3       ctg_analyst_layer             ctg_care_cct_interactions
# 0       ctg_analyst_layer                            cases_uids
# 2       ctg_analyst_layer                        ctg_care_cases
# 18               care_dwh                     helpful_votes_all
# 17               care_dwh                     helpful_votes_all
# 5           ctg_analytics                          dim_campaign
# 11          ctg_analytics                          dim_page_url
# 25      ctg_analytics_src  trn_getdata_form_generic_information
# 26               matt_dwh                 ttl_retail_activation
# 27               matt_dwh                  ttl_retail_printfile
# 28               matt_dwh                     ttl_retail_revoke
# 29               matt_dwh                    ttl_retail_upgrade
# 30               matt_dwh                            tto_orders
# 31               matt_dwh                  tto_sessionstart_log
# 24          ctg_analytics              sub_auth_credit_campaign
# 23        consumer_source         src_sw_wfm_schedule_slot_stat
#
#                                    Data Lake Key  \
# 13                ent_dwr_dwh.dw_as_standardized
# 16                ent_dwr_dwh.dw_cc_standardized
# 21                         ent_elm_dwh.elm_agent
# 22         ent_elm_dwh.elm_agent_additional_info
# 6              ent_ewfm_tcsdbowner_dwh.acd_login
# 12           ent_ewfm_tcsdbowner_dwh.aud_det_seg
# 7                ent_ewfm_tcsdbowner_dwh.seg_cat
# 8     ent_ewfm_tcsdbowner_dwh.seg_code_cat_assoc
# 9              ent_ewfm_tcsdbowner_dwh.tcs_login
# 10             ent_ewfm_tcsdbowner_dwh.time_zone
# 4   intuit_identity_lifecycle_dwh.person_profile
# 19          ivr_rpt.agg_inet_billing_transaction
# 14             tax_dm.fact_auth_id_sompleted_sku
# 15                    tax_dm.fact_sf_b2c_contact
# 1                     tax_rpt.agg_user_care_case
# 20                tax_rpt.request_uuid_info_ty19
# 3              tax_rpt.rpt_care_cct_interactions
# 0                           tax_rpt.rpt_case_uid
# 2                      tax_rpt.rpt_ctg_care_case
# 18              tax_src.axc_ca_helpful_votes_all
# 17              tax_src.axc_us_helpful_votes_all
# 5                    tax_src.dim_campaign_global
# 11                   tax_src.dim_page_url_global
# 25              tax_src.getdata_form_generic_raw
# 26             tax_src.src_ttl_retail_activation
# 27              tax_src.src_ttl_retail_printfile
# 28                 tax_src.src_ttl_retail_revoke
# 29                tax_src.src_ttl_retail_upgrade
# 30                        tax_src.src_tto_orders
# 31              tax_src.src_tto_sessionstart_log
# 24       tax_src.sub_auth_credit_campaign_global
# 23     tax_ws.src_sw_wfm_schedule_slot_stat_temp
#
#                  Data Lake Schema                     Data Lake Table
# 13                    ent_dwr_dwh                  dw_as_standardized
# 16                    ent_dwr_dwh                  dw_cc_standardized
# 21                    ent_elm_dwh                           elm_agent
# 22                    ent_elm_dwh           elm_agent_additional_info
# 6         ent_ewfm_tcsdbowner_dwh                           acd_login
# 12        ent_ewfm_tcsdbowner_dwh                         aud_det_seg
# 7         ent_ewfm_tcsdbowner_dwh                             seg_cat
# 8         ent_ewfm_tcsdbowner_dwh                  seg_code_cat_assoc
# 9         ent_ewfm_tcsdbowner_dwh                           tcs_login
# 10        ent_ewfm_tcsdbowner_dwh                           time_zone
# 4   intuit_identity_lifecycle_dwh                      person_profile
# 19                        ivr_rpt        agg_inet_billing_transaction
# 14                         tax_dm          fact_auth_id_sompleted_sku
# 15                         tax_dm                 fact_sf_b2c_contact
# 1                         tax_rpt                  agg_user_care_case
# 20                        tax_rpt              request_uuid_info_ty19
# 3                         tax_rpt           rpt_care_cct_interactions
# 0                         tax_rpt                        rpt_case_uid
# 2                         tax_rpt                   rpt_ctg_care_case
# 18                        tax_src            axc_ca_helpful_votes_all
# 17                        tax_src            axc_us_helpful_votes_all
# 5                         tax_src                 dim_campaign_global
# 11                        tax_src                 dim_page_url_global
# 25                        tax_src            getdata_form_generic_raw
# 26                        tax_src           src_ttl_retail_activation
# 27                        tax_src            src_ttl_retail_printfile
# 28                        tax_src               src_ttl_retail_revoke
# 29                        tax_src              src_ttl_retail_upgrade
# 30                        tax_src                      src_tto_orders
# 31                        tax_src            src_tto_sessionstart_log
# 24                        tax_src     sub_auth_credit_campaign_global
# 23                         tax_ws  src_sw_wfm_schedule_slot_stat_temp

# %%
# merge alation catalog and vertica descriptions on table key name
df_table_definitions = pd.merge(df_alation_catalog[['key','schema','title','steward:user','intuit_classification']], 
                       df_vertica_table_extended[['key','title','description']], on='key')

df_table_definitions.rename(columns={'title_x':'title'}, inplace=True)

df_table_definitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   key                    0 non-null      object
#  1   schema                 0 non-null      object
#  2   title                  0 non-null      object
#  3   steward:user           0 non-null      object
#  4   intuit_classification  0 non-null      object
#  5   title_y                0 non-null      object
#  6   description            0 non-null      object
# dtypes: object(7)
# memory usage: 0.0+ bytes

# %% [markdown]
# Processing stopped here - no new data lake table definition to bring in

# %% [markdown]
# ### Read DSE catalog_set definitions
#
# This will be used as an exclude list - i.e. do not include object keys for which there is already an uploaded definition

# %%
# Initiatize cg_datasets data frame
df_cg_datasets = pd.DataFrame( 
                columns = ['key','data_file'])

# Read the list of Hive folders 
for d in os.listdir(GITHUB['LOCAL_PATH']):
    catalog_path = os.path.join(GITHUB['LOCAL_PATH'], d, GITHUB['DATA_CATALOG_FOLDER_NAME'])
    print("")
    if os.path.isdir(catalog_path):
        print(f"Processing content of {catalog_path}")
        f_count = 0
        for f in os.listdir(catalog_path):
            try:
                df_tmp = pd.read_csv(os.path.join(catalog_path, f),  usecols=['key'])
                df_tmp['data_file'] = f
#                 print(f"  adding {f} content")
                df_cg_datasets = pd.concat([df_cg_datasets, df_tmp], ignore_index=True, sort=True)
                f_count += 1
            except:
                pass
        print(f"   Read {f_count} input files")
        
    else:
        print(f"Skipping {catalog_path} - does not exist")


df_cg_datasets.shape
# Out:
# Processing content of S:/Development/github/intuit/cg_datasets/hive\bup_dm\datacatalog
#    Read 34 input files
#
# Processing content of S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog
#    Read 15 input files
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\care_rpt\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\catax_src\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\ca_tax_src\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\cgan_ustax_published\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\cg_dwh\datacatalog - does not exist
#
# Processing content of S:/Development/github/intuit/cg_datasets/hive\common_dm\datacatalog
#    Read 2 input files
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\digital_assist\datacatalog - does not exist
#
# Processing content of S:/Development/github/intuit/cg_datasets/hive\fg_dwh\datacatalog
#    Read 2 input files
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\hr_dm\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\hr_src\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\hr_stg\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\ivr_rpt\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\ivr_src\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\ivr_stg\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\mint\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\sbseg_src_parity\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\schema\datacatalog - does not exist
#
# Processing content of S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog
#    Read 86 input files
#
# Processing content of S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog
#    Read 29 input files
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\smartmoney_stg\datacatalog - does not exist
#
# Processing content of S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog
#    Read 118 input files
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\tax_dm_prf\datacatalog - does not exist
#
# Processing content of S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog
#    Read 39 input files
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\tax_rpt_prf\datacatalog - does not exist
#
# Processing content of S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog
#    Read 183 input files
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\tax_src_ca\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\tax_src_prf\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\tax_stg\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\tax_ws\datacatalog - does not exist
#
# Skipping S:/Development/github/intuit/cg_datasets/hive\tax_ws_prf\datacatalog - does not exist
# (16522, 2)

# %%
df_cg_datasets['cg_datasets'] = True

df_cg_datasets.head(25)
# Out:
#                                data_file  \
# 0              bup_dm.config_etl_job.csv
# 1              bup_dm.config_etl_job.csv
# 2              bup_dm.config_etl_job.csv
# 3              bup_dm.config_etl_job.csv
# 4              bup_dm.config_etl_job.csv
# 5              bup_dm.config_etl_job.csv
# 6              bup_dm.config_etl_job.csv
# 7              bup_dm.config_etl_job.csv
# 8         bup_dm.data_checker_report.csv
# 9         bup_dm.data_checker_report.csv
# 10        bup_dm.data_checker_report.csv
# 11        bup_dm.data_checker_report.csv
# 12        bup_dm.data_checker_report.csv
# 13        bup_dm.data_checker_report.csv
# 14        bup_dm.data_checker_report.csv
# 15        bup_dm.data_checker_report.csv
# 16        bup_dm.data_checker_report.csv
# 17        bup_dm.data_checker_report.csv
# 18        bup_dm.data_checker_report.csv
# 19        bup_dm.data_checker_report.csv
# 20  bup_dm.data_checker_report_stage.csv
# 21  bup_dm.data_checker_report_stage.csv
# 22  bup_dm.data_checker_report_stage.csv
# 23  bup_dm.data_checker_report_stage.csv
# 24  bup_dm.data_checker_report_stage.csv
#
#                                                   key  cg_datasets
# 0                                              bup_dm         True
# 1                               bup_dm.config_etl_job         True
# 2                   bup_dm.config_etl_job.schema_name         True
# 3            bup_dm.config_etl_job.max_processed_date         True
# 4                 bup_dm.config_etl_job.etl_type_name         True
# 5               bup_dm.config_etl_job.job_load_status         True
# 6            bup_dm.config_etl_job.last_modified_time         True
# 7                      bup_dm.config_etl_job.job_name         True
# 8                          bup_dm.data_checker_report         True
# 9        bup_dm.data_checker_report.data_checker_name         True
# 10     bup_dm.data_checker_report.validation_datetime         True
# 11                bup_dm.data_checker_report.datasets         True
# 12            bup_dm.data_checker_report.partner_name         True
# 13              bup_dm.data_checker_report.event_date         True
# 14               bup_dm.data_checker_report.dataset_1         True
# 15          bup_dm.data_checker_report.metric_1_value         True
# 16               bup_dm.data_checker_report.dataset_2         True
# 17          bup_dm.data_checker_report.metric_2_value         True
# 18       bup_dm.data_checker_report.validation_result         True
# 19                bup_dm.data_checker_report.is_valid         True
# 20                   bup_dm.data_checker_report_stage         True
# 21     bup_dm.data_checker_report_stage.pipeline_name         True
# 22  bup_dm.data_checker_report_stage.validation_da...         True
# 23   bup_dm.data_checker_report_stage.validation_name         True
# 24       bup_dm.data_checker_report_stage.dimension_1         True

# %% [markdown]
# ### Remove columns already in cg datasets

# %%
df_new_definitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9141 entries, 0 to 9140
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   key                    9141 non-null   object
#  1   schema                 9141 non-null   object
#  2   title                  9141 non-null   object
#  3   description            9141 non-null   object
#  4   steward:user           9141 non-null   object
#  5   intuit_classification  9141 non-null   object
# dtypes: object(6)
# memory usage: 428.6+ KB

# %%
# use merge left join - substract 
# number of columns that will be remove
pd.merge(df_new_definitions,df_cg_datasets, on='key').shape
# Out:
# (2617, 8)

# %%
pd.merge(df_new_definitions,df_cg_datasets, on='key').head()
# Out:
#                                             key  schema     title  \
# 0      tax_dm.agg_sessions_to_complete.tax_year  tax_dm  Tax Year
# 1  tax_dm.helper_bot_like_agent_domain.tax_year  tax_dm  Tax Year
# 2      tax_dm.dim_date_tax_year_season.tax_year  tax_dm  Tax Year
# 3                           tax_dm.prs.tax_year  tax_dm  Tax Year
# 4                  tax_dm.prs_verbatim.tax_year  tax_dm  Tax Year
#
#                                          description steward:user  \
# 0  <table border="0" cellpadding="0" cellspacing=...
# 1  <table border="0" cellpadding="0" cellspacing=...
# 2  <table border="0" cellpadding="0" cellspacing=...
# 3  <table border="0" cellpadding="0" cellspacing=...
# 4  <table border="0" cellpadding="0" cellspacing=...
#
#   intuit_classification                                data_file  cg_datasets
# 0            restricted      tax_dm.agg_sessions_to_complete.csv         True
# 1            restricted  tax_dm.helper_bot_like_agent_domain.csv         True
# 2            restricted      tax_dm.dim_date_tax_year_season.csv         True
# 3            restricted                  tax_dm.prs_verbatim.csv         True
# 4            restricted                  tax_dm.prs_verbatim.csv         True

# %%
df_new_definitions_scrubbed = pd.merge(df_new_definitions,df_cg_datasets, on='key', how='left')
df_new_definitions_scrubbed['cg_datasets'].fillna(False, inplace=True)

df_new_definitions_scrubbed[['cg_datasets','key']].groupby('cg_datasets').count()
# Out:
#               key
# cg_datasets
# False        6530
# True         2617

# %%
df_new_definitions_scrubbed = df_new_definitions_scrubbed[~ df_new_definitions_scrubbed['cg_datasets']]
df_new_definitions_scrubbed.shape
# Out:
# (6530, 8)

# %%
# generate datafile names for export
key_list = df_new_definitions_scrubbed['key'].tolist()
# print(key_list)

data_file_list = []

for k in key_list:
    k_array = k.split(".")
    data_file_list.append(k_array[0]+"/"+GITHUB['DATA_CATALOG_FOLDER_NAME']+"/"+k_array[1]+\
                          "_"+GITHUB['CATALOG_FILE_NAME_SUFFIX']+".csv")
    
# print(data_file_list)

df_new_definitions_scrubbed['data_file'] = data_file_list

# %%
df_new_definitions_scrubbed.head()
# Out:
#                                                  key               schema  \
# 0  bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 1  bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 2  bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 3  bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 4  bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
#
#       title                                        description steward:user  \
# 0  Tax Year  <table border="0" cellpadding="0" cellspacing=...
# 1  Tax Year  <table border="0" cellpadding="0" cellspacing=...
# 2  Tax Year  <table border="0" cellpadding="0" cellspacing=...
# 3  Tax Year  <table border="0" cellpadding="0" cellspacing=...
# 4  Tax Year  <table border="0" cellpadding="0" cellspacing=...
#
#   intuit_classification                                          data_file  \
# 0            restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 1            restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 2            restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 3            restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 4            restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
#
#    cg_datasets
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %% [markdown]
# ### Export new definitions to DSE GITHUB repo

# %%
# final data set
df_new_definitions_scrubbed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6530 entries, 0 to 9146
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   key                    6530 non-null   object
#  1   schema                 6530 non-null   object
#  2   title                  6530 non-null   object
#  3   description            6530 non-null   object
#  4   steward:user           6530 non-null   object
#  5   intuit_classification  6530 non-null   object
#  6   data_file              6530 non-null   object
#  7   cg_datasets            6530 non-null   bool
# dtypes: bool(1), object(7)
# memory usage: 414.5+ KB

# %%
df_new_definitions_scrubbed.duplicated(subset=['key']).sum()
# Out:
# 0

# %%
# sort and add legacy tag to definition
df_new_definitions_scrubbed.sort_values(by='data_file', ascending = True, inplace=True)
df_new_definitions_scrubbed['description'] = "[Vertica Legacy] " + df_new_definitions_scrubbed['description'] 
df_new_definitions_scrubbed.head(25)
# Out:
#                                                    key               schema  \
# 6    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 2    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 9    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 4    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 1    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 7    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 3    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 5    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 0    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 8    bud_clickstream_dwh.ecs_clickstream_turbotax_t...  bud_clickstream_dwh
# 355  bup_dm.dummy_helper_revenue_tracking_event_cgd...               bup_dm
# 365  bup_dm.dummy_helper_revenue_tracking_event_cgd...               bup_dm
# 439  bup_dm.dummy_helper_revenue_tracking_event_cgd...               bup_dm
# 449  bup_dm.dummy_helper_revenue_tracking_event_cgd...               bup_dm
# 270  bup_dm.dummy_helper_revenue_tracking_event_cgd...               bup_dm
# 356  bup_dm.dummy_helper_revenue_tracking_event.sit...               bup_dm
# 366  bup_dm.dummy_helper_revenue_tracking_event.dwh...               bup_dm
# 440  bup_dm.dummy_helper_revenue_tracking_event.eve...               bup_dm
# 450  bup_dm.dummy_helper_revenue_tracking_event.eve...               bup_dm
# 271  bup_dm.dummy_helper_revenue_tracking_event.dwh...               bup_dm
# 272    bup_dm.helper_placement_mapping.dwh_update_time               bup_dm
# 562               bup_src.bup_pplat_audit.partner_name              bup_src
# 467          bup_src.bup_pplat_audit.created_timestamp              bup_src
# 514          bup_src.bup_pplat_audit.updated_timestamp              bup_src
# 443  bup_src.bup_pplat_revenuetracking_bkp.event_da...              bup_src
#
#                             title  \
# 6                        Tax Year
# 2                        Tax Year
# 9                        Tax Year
# 4                        Tax Year
# 1                        Tax Year
# 7                        Tax Year
# 3                        Tax Year
# 5                        Tax Year
# 0                        Tax Year
# 8                        Tax Year
# 355                     Site Name
# 365  Data Warehouse Creation Time
# 439                Event Datetime
# 449               Event Type Code
# 270    Data Warehouse Update Time
# 356                     Site Name
# 366  Data Warehouse Creation Time
# 440                Event Datetime
# 450               Event Type Code
# 271    Data Warehouse Update Time
# 272    Data Warehouse Update Time
# 562                  Partner Name
# 467             Created Timestamp
# 514             Updated Timestamp
# 443                Event Datetime
#
#                                            description steward:user  \
# 6    [Vertica Legacy] <table border="0" cellpadding...
# 2    [Vertica Legacy] <table border="0" cellpadding...
# 9    [Vertica Legacy] <table border="0" cellpadding...
# 4    [Vertica Legacy] <table border="0" cellpadding...
# 1    [Vertica Legacy] <table border="0" cellpadding...
# 7    [Vertica Legacy] <table border="0" cellpadding...
# 3    [Vertica Legacy] <table border="0" cellpadding...
# 5    [Vertica Legacy] <table border="0" cellpadding...
# 0    [Vertica Legacy] <table border="0" cellpadding...
# 8    [Vertica Legacy] <table border="0" cellpadding...
# 355  [Vertica Legacy] Site name for remote and BM e...
# 365  [Vertica Legacy] The date/time when this recor...
# 439  [Vertica Legacy] This is the date/time when th...
# 449  [Vertica Legacy] A code for the event type tha...
# 270  [Vertica Legacy] The date/time when this recor...
# 356  [Vertica Legacy] Site name for remote and BM e...
# 366  [Vertica Legacy] The date/time when this recor...
# 440  [Vertica Legacy] This is the date/time when th...
# 450  [Vertica Legacy] A code for the event type tha...
# 271  [Vertica Legacy] The date/time when this recor...
# 272  [Vertica Legacy] The date/time when this recor...
# 562  [Vertica Legacy] Indicates the outsource partn...
# 467  [Vertica Legacy]  Timestamp this record was cr...
# 514  [Vertica Legacy] The timestamp of when the row...
# 443  [Vertica Legacy] This is the date/time when th...
#
#     intuit_classification                                          data_file  \
# 6              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 2              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 9              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 4              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 1              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 7              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 3              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 5              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 0              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 8              restricted  bud_clickstream_dwh/datacatalog/ecs_clickstrea...
# 355            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 365            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 439            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 449            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 270            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 356            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 366            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 440            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 450            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 271            restricted  bup_dm/datacatalog/dummy_helper_revenue_tracki...
# 272            restricted  bup_dm/datacatalog/helper_placement_mapping_ve...
# 562            restricted  bup_src/datacatalog/bup_pplat_audit_vertica-le...
# 467            restricted  bup_src/datacatalog/bup_pplat_audit_vertica-le...
# 514            restricted  bup_src/datacatalog/bup_pplat_audit_vertica-le...
# 443            restricted  bup_src/datacatalog/bup_pplat_revenuetracking_...
#
#      cg_datasets
# 6          False
# 2          False
# 9          False
# 4          False
# 1          False
# 7          False
# 3          False
# 5          False
# 0          False
# 8          False
# 355        False
# 365        False
# 439        False
# 449        False
# 270        False
# 356        False
# 366        False
# 440        False
# 450        False
# 271        False
# 272        False
# 562        False
# 467        False
# 514        False
# 443        False

# %%
# export as a single CSV file
df_export = df_new_definitions[['key','title','description','steward:user','intuit_classification']] 
df_export.to_csv('dl_new_definitions.csv', index=False)

# %%
# export into multiple CSV files, one per schema (i.e. key.split()[0]+"."+key.split()[1]+".csv")
# loop through export file list
csv_file_list = df_new_definitions_scrubbed['data_file'].unique().tolist()


for f in csv_file_list:
    # create table folder if not exists
    fx = f.split("/")
    f_path = os.path.join(GITHUB['LOCAL_PATH'],fx[0],fx[1])
#     print(f_path)
    os.makedirs(f_path,exist_ok=True)
    f_path = os.path.join(f_path,fx[2])    
    print(f"Exported: {f_path}")

    df_export = df_new_definitions_scrubbed[df_new_definitions_scrubbed['data_file'] == f][['key','title','description','steward:user','intuit_classification']] 
    df_export.to_csv(f_path, index=False)
# Out:
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2020_v2_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2020_v3_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2020_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2021_v1_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2021_v2_hive_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2021_v2_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2021_v3_hive_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2021_v3_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2021_v4_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bud_clickstream_dwh\datacatalog\ecs_clickstream_turbotax_ty2021_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_dm\datacatalog\dummy_helper_revenue_tracking_event_cgde_52818_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_dm\datacatalog\dummy_helper_revenue_tracking_event_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_dm\datacatalog\helper_placement_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\bup_pplat_audit_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\bup_pplat_revenuetracking_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\bup_pplat_revenuetracking_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\helper_state_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\hive_sample_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\reload_rakuten_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_external_marcus_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_adagency_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_application_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_campaign_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_contentgroupmapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_contract_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_contractmapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_contractversion_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_offering_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_page_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_partner_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_partnercontent_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_partnercontentgroup_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_placement_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pplat_vertical_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pq_partner_request_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pq_partner_response_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pq_partner_src_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pq_partner_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pq_prequalworkflow_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pq_response_offer_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\src_pq_vertical_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\stg_external_marcus_clean_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\stg_helper_auto_decline_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\stg_helper_funnel_stage_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\tmp_revenue_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\bup_src\datacatalog\v_partner_commission_junction_etl_test_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_27thjan_bk_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_bk_20jan_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_delete_27thjan_bk_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_ingest_27thjan_bk_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_latinx_geoscape_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_latinx_geoscape_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_latinx_geoscape_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_latinx_namesake_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_latinx_namesake_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_latinx_namesake_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\cgdata_taxml_dwh\datacatalog\taxml_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\common_dm\datacatalog\cfg_tax_etl_job_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\common_dm\datacatalog\dim_care_date_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\common_dm\datacatalog\dim_care_time_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\common_dm\datacatalog\dim_cg_current_tax_year_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\common_dm\datacatalog\dim_source_systems_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\application_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\asset_variables_test_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\asset_variables_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\bu_user_role_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\exp_user_role_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_assets_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_metadata_db_test_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_metadata_db_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_metadata_summarized_test_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_metadata_summarized_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_metric_info_test_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_metric_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_proposals_temp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_proposals_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_sdkinfo_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_start_report_v2_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_start_report_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_user_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\experiment_version_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\ixp_assignment_raw_v2_temp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\ixp_experiment_starts_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\ixp_mis_match_check_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\ixp_mis_match_v2_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\ixp_mis_match_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\ixp_processed_metadata_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\ixp_ver_mismatch_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\mab_poc_v2_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\mab_poc_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ixp_dwh\datacatalog\user_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\clickstream_sm_login_n_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\clickstream_sm_login_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\config_etl_job_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\dim_sm_login_app_type_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\dim_sm_login_campaign_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\dim_sm_login_channel_group_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\dim_sm_login_scope_area_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\fact_sm_login_tmp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\helper_mint_insights_users_current_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\helper_mint_insights_users_holdout_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\helper_partner_account_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\helper_transaction_category_group_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\helper_user_lookup_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\v_marketing_fact_sm_login_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_dm\datacatalog\v_sm_count_by_goal_type_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\account_bank_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\account_credit_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\account_fdp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\account_investment_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\account_loan_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\account_property_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\account_realestate_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\account_unclassified_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\credit_profile_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\credit_score_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\credit_trade_line_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\ctodev_consent_appevents_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\reload_rakuten_signature_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\reload_signature_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\src_gpc_ctodev_consent_appevents_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\src_quickbase_revenue_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\src_rakuten_mint_hist_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\src_rakuten_signature_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\user_goal_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\user_identity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\user_login_history_mobile_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\user_networth_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\user_preferences_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\user_profile_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\users_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\smartmoney_src\datacatalog\v_sm_count_transactions_since_last_login_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\agg_auth_id_revenue_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\agg_auth_id_state_efile_status_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\agg_completed_orders_ranked_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\agg_completed_orders_ranked_vw_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\agg_fed_customer_efile_status_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\agg_pro_daily_logged_work_hours_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\agg_pro_daily_productive_hours_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\c360_marketing_attribute_non_taxyear_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\c360_marketing_attribute_taxyear_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\ck_all_matched_members_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\ck_matched_members_2018_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\ck_matched_members_2019_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\ck_matched_members_2020_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\ck_matched_members_2021_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\ck_matched_members_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_ab_test_recipe_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_agent_state_time_type_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_agent_state_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_agent_status_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_auth_delta_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_authorization_level_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_bundle_rollup_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_care_search_source_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_cc_vendor_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_customer_definition_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_customer_type_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_efile_payment_method_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_filing_status_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_hours_of_operation_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_nlac_search_kw_bucket_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_nlac_search_kw_subbucket_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_product_alias_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_product_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_routing_profile_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_source_application_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_state_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_tax_employer_hist_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_tax_product_info_profile_type_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_tile_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_training_class_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\dim_tta_enrollment_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_as_standardized_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_auth_id_completed_user_agent_parity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_auth_id_nlac_crm_attributes_clickstream_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_auth_id_refund_drop_in_session_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_auth_id_refund_drop_taxml_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_auth_id_risk_model_predictions_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_cc_source_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_cc_standardized_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_cs_account_txn_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_cs_inquiry_txn_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_cs_public_record_txn_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_efile_status_tmp_achandeck_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_financial_events_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_life_event_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_marketing_tto_snc_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_mktg_proactive_saves_customer_success_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_mktg_proactive_saves_elc_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_mktg_proactive_saves_tax_amendment_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_mktg_proactive_saves_tax_clickstream_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_mktg_proactive_saves_tax_profile_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_mrktg_turbotax_txn_shelby_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_sf_b2c_case1_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_sf_b2c_case_history_raw_vnf_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_sf_b2c_contact_copy_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_sf_b2c_contact_verbatim_cgde50822_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_tax_digital_assistant_session_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_tax_w2_import_eligibility_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_tax_w2_metric_hist_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_tax_w2_metric_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\fact_taxprep_session_delta_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_attrition_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_cv_dne_suppress_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_cv_get_pii2_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_cv_get_pii_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_cv_get_pii_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_dne_address_domain_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_dne_address_local_part_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_location_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_mktg_item_product_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_mktg_product_rank_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_no_tax_state_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_profile_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_seasonal_agent_detail_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_segment_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_site_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\helper_tax_case_session_id_mapping_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\lk_product_completed_sku_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\lkp_customer_efs_non_rt_order_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\lkp_customer_efs_rt_order_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\lkp_customer_tto_orders_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\lkp_efs_application_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\lkp_item_alias_rank_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\lkp_item_alias_rank_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\lkp_product_completed_sku_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\marketing_first_party_attribute_parity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\nlac_customer_behavior_detailed_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\nlac_customer_retention_levers_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\retention_analytics_master_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\sm_temp_auth_log_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\snap_test1_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\snap_test2_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\snap_test3_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\snap_test5_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\snap_tta_metric_aug08_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\snap_tta_metric_test1_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\snap_tta_metric_test_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stage_act_dim_product_base_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stage_act_dim_sku_rollup_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stage_act_helper_mktg_product_rank_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stage_act_lkp_item_alias_rank_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stage_dim_bundle_rollup_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stage_lkp_item_alias_rank_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stg_accepted_refund_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stg_efs_filing_status_change_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stg_etx_orders_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\stg_sub_authentication_first_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\sub_clickstream_prior_year_taxprep_method_first_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\sub_clickstream_recipe_assignment_first_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\sub_customer_segment_delta_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\sub_customer_segment_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\sub_tax_digital_assistant_session_intent_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\sub_taxorder_completed_rankedk_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\temp_helper_exp_assignment_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\tmp_auth_id_no_stimulus_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\ttl_auth_scope_master_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\tto_abandonment_screen_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\tto_abandonment_topic_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\tto_test_records_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\ty18_active_tta_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\v_dim_marketing_taxcust_profile_list_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\v_marketing_first_party_attribute_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\v_sm_temp_auth_log_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\v_tta_marketing_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\v_ttd_retail_registrations_cy_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\v_ttd_retail_registrations_py_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\view_quicketl_sub_authentication_first_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\view_quicketl_sub_authorization_first_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\vw_dim_agent_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_dm\datacatalog\vw_expert_productivity_customer_serving_time_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agent_details_51346_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agent_details_proficiency_51346_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_agent_level_call_transfer_metric_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_auth_bundle_upsell_cy_vw_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_auth_bundle_upsell_vw_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_auth_id_revenue_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_clickstream_auth_last_event_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_customer_revenue_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_kochava_event_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_marketing_analytics_delta_2019_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_marketing_analytics_delta_2020_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_marketing_analytics_delta_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\agg_marketing_analytics_parity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\auth_analytics_base_new_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\auth_analytics_base_parity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\auth_entitlement_daily_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\auth_sku_changes_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ctg_care_call_auth_entitlement_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ctg_care_call_auth_entitlement_snapshot_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ctg_care_cases_voc_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ctg_care_cct_interactions_vw_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\exec_dashboard_metric_values_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\fact_case_level_call_transfer_metric_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\fi_mktg_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\finance_analytics_report_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\marketing_analytics_master_parity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\marketing_analytics_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\marketing_session_analytics_master_parity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\marketing_visitor_analytics_master_parity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\monetization_analytics_master_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\monetization_analytics_master_snapshot_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\monetization_analytics_master_ytd_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\postcard_schedules_taxml_analytics_master_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\postcard_schedules_taxml_analytics_master_hist_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\postcard_schedules_taxml_analytics_master_snapshot_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\postcard_schedules_taxml_analytics_master_ytd_2019_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\postcard_schedules_taxml_analytics_master_ytd_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\postcard_schedules_taxml_analytics_master_ytd_hist_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\postcard_schedules_taxml_analytics_master_ytd_snapshot_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\product_analytics_master_parity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\product_analytics_master_ytd_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\product_analytics_master_ytd_vw_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\request_uuid_info_prf_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\request_uuid_info_ty19_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\retention_analytics_master_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\retention_analytics_master_ytd_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_auth_fact_clickstream_daily_summary_historical_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_auth_fact_clickstream_daily_summary_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_ctg_care_case_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_customer_extension_filings_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_testing_analytics_master_auth2_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_testing_analytics_master_mobile_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_testing_analytics_master_visitor_backup_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_testing_analytics_master_visitor_bkp_11_01_2021_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_testing_analytics_master_visitor_bkp_2019_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_testing_analytics_master_visitor_bkp_test_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_testing_analytics_master_visitor_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_testing_analytics_master_visitor_tbkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\rpt_testing_analytics_master_visitor_test_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\start_sku_cgde_43429_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\t1_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\temp1_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\temp2_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\testing_analytics_master_auth_tax_rpt_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\testing_analytics_master_visitor_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\tmp_first_complete_timestamp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\tmp_marketing1b_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ttl_activity_daily_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ttl_activity_daily_snapshot_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ttl_activity_daily_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ttl_agg_auth_master_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ttl_agg_auth_master_snapshot_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_rpt\datacatalog\ttl_agg_auth_master_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\aca_screen_vw_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\adtp_tto_abandonment_src_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\agg_auth_id_revenue_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\agg_taxml_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\agg_taxml_hist_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\agg_taxml_snapshot_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\agg_taxml_ytd_bkp_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\agg_taxml_ytd_hist_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\agg_taxml_ytd_snapshot_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\auth_sku_activity_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_analytic_events_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_bookmarks_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_communities_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_helpful_votes_all_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_post_attributes_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_posts_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_products_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_replies_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_roles_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_summary_box_feedbacks_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_summary_boxes_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_taggings_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_tags_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_topic_things_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_topics_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_users_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_ca_votes_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_analytic_events_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_bookmarks_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_communities_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_helpful_votes_all_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_post_attributes_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_posts_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_products_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_replies_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_roles_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_summary_box_feedbacks_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_summary_boxes_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_taggings_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_tags_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_topic_things_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_topics_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_users_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\axc_us_votes_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\behavioral_analytics_master_global_prf_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\cfg_exp_etl_job_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\cg_filing_taxml_payload_new_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\cg_filing_taxml_payload_nodup_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\tax_src\datacatalog\cg_filing_taxml_payload_ty19_vertica-legacy.csv
# ...
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_ira_contributory_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_ira_contributory_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_rollover_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_rollover_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_rollover_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_spending_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_spending_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_spending_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_tracking_conversion_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_tracking_conversion_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_tracking_conversion_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_tracking_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_tracking_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_tracking_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_versioned_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_versioned_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_versioned_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\offer_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\shard_to_pod_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\shard_to_pod_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\shard_to_pod_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\shared_category_customization_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\shared_category_customization_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\shared_category_customization_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\sneak_preview_feature_source_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\sneak_preview_feature_source_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\sneak_preview_feature_source_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\stats_fi_login_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\stats_fi_login_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\stats_fi_login_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\stats_fi_search_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\stats_fi_search_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\stats_fi_search_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_bankcc_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_bankcc_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_bankcc_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_investment_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_investment_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_investment_usertag_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_investment_usertag_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_investment_usertag_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_investment_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_loan_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_loan_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_loan_usertag_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_loan_usertag_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_loan_usertag_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_loan_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_usertag_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_usertag_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\transaction_usertag_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_budget_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_budget_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_budget_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_category_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_category_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_category_relationship_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_category_relationship_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_category_relationship_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_category_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_data_request_detail_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_data_request_detail_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_data_request_detail_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_event_reminder_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_event_reminder_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_event_reminder_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_fdp_migration_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_fdp_migration_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_fdp_migration_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_account_contribution_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_account_contribution_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_account_contribution_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_account_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_account_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_account_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_action_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_action_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_action_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_contribution_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_contribution_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_contribution_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_property_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_property_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_property_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_goal_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_login_history_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_login_history_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_login_history_mobile_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_login_history_mobile_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_login_history_mobile_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_login_history_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_lookup_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_lookup_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_lookup_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_mobile_token_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_mobile_token_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_mobile_token_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_networth_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_networth_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_networth_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_preferences_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_preferences_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_preferences_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_profile_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_profile_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_profile_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_property_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_property_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_property_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_segment_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_segment_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_segment_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_tag_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_tag_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_tag_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_transactionrule_amount_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_transactionrule_amount_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_transactionrule_amount_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_transactionrule_description_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_transactionrule_description_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_transactionrule_description_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\user_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\yodlee_job_delete_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\yodlee_job_ingest_vertica-legacy.csv
# Exported: S:/Development/github/intuit/cg_datasets/hive\ued_mint_dwh\datacatalog\yodlee_job_vertica-legacy.csv
